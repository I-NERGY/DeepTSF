# %%
library(forecast)
library(urca)
library(tseries)
library(zoo)
library(xts)
library(repr)
library(dplyr)
library(ggfortify)
library(astsa)

# %% [markdown]
# # Load data

# %%
data <- read.table("../../RDN/Load Data (2018-2019)/artifacts/load_60min.csv", sep=',', header=TRUE)
y <- data['Load']

# %% [markdown]
# # Create time series

# %%
start.time <- as.POSIXlt("2018-01-01 00:00:00")
end.time <- as.POSIXlt("2019-12-31 23:00:00")
j <- xts(y, seq(start.time, end.time, by=3600), frequency=24)

print("Univariate time series created:")
head(as.matrix(tsdat))
# Out:
# [1] "Univariate time series created:"
#                     Load
# 2018-01-01 00:00:00 18555.88
# 2018-01-01 01:00:00 18001.48
# 2018-01-01 02:00:00 17017.79
# 2018-01-01 03:00:00 16187.43
# 2018-01-01 04:00:00 15621.66
# 2018-01-01 05:00:00 15259.36

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Time series plot

# %%
options(repr.plot.width=20, repr.plot.height=6)
plot(j, type="l", col='red', lwd=0.5, main="Total Active Energy", ylab="kwh")
# Out:
# plot without title

# %% [markdown]
# ## Outlier handling

# %% [markdown]
# 2 methods are used to detect outliers (forecast package):
# 1. tsclean which implements loess decomposition of time series to identify and replace outliers
# 2. tsoutliers function which implements the Chen and Liu method
# Results are exactly the same for both. No outliers are detected at all.

# %%
setdiff(tsclean(j)$Load, j$Load)
# Out:
# numeric(0)

# %%
tsoutliers(j)
# Out:
# $index
# integer(0)
#
# $replacements
#      Load

# %% [markdown]
# ## Transforms

# %%
dj=diff(j)
lj = log(j)
# lj = log(j)

# %%
options(repr.plot.width=20, repr.plot.height=15)
par(mfrow=c(3,2)) # set up the graphics
plot(j,type="l", col='red', lwd=1,main="Time Series plot of Total Active Energy", ylab="kwh")
hist(j, nclass=25, main="Histogram of Total Active Energy")
plot(lj,type="l", col='red', lwd=1,main="Differences of log of Total Active Energy")
hist(lj, nclass=25, main="Histogram of differences of log of Total Active Energy")
plot(dj,type="l", col='red', lwd=1,main="Log of Total Active Energy", ylab="Log of kwh")
hist(dj, nclass=25, main="Histogram of log of Total Active Energy")
# Out:
# Plot with title “Histogram of log of Total Active Energy”

# %%
par(mfrow=c(2,2)) # set up the graphics
acf(ts(j, freq=1), 100, main="ACF of Total Active Load") # autocorrelation function plot
pacf(ts(j, freq=1), 100, main="PACF of Total Active Energy") # partial autocorrelation function
acf(ts(dj, freq=1), 100, main="ACF of differences of Total Active Energy", na.action = na.pass)
pacf(ts(dj, freq=1), 100, main="PACF of differences of Total Active Energy", na.action = na.pass)
# Out:
# Plot with title “PACF of differences of Total Active Energy”

# %% [markdown]
# It is observed that following the diff transformations the time series seems much closer to stationary, effectively removing the trend. This demonstrated the need for on differentiation term. Also skewness of the distribution is mitigated. Heteroskedasticity still appears even in the log transformation and therefore it wont be used further. Seasonal patterns are also observed leading to exploration of decomposition.

# %% [markdown]
# ## Decomposition
# The time series obviously seems to require decomposition

# %%
seasonal <- read.table("../../RDN/Load Data (2018-2019)/artifacts/decomposition/rdn_daily_seasonality.csv", sep=',', header=TRUE)
y <- seasonal['seasonal']
seasonal_daily <- xts(y, seq(start.time, end.time, by=3600), frequency=24)

seasonal <- read.table("../../RDN/Load Data (2018-2019)/artifacts/decomposition/rdn_weekly_seasonality.csv", sep=',', header=TRUE)
y <- seasonal['seasonal']
seasonal_weekly <- xts(y, seq(start.time2, end.time2, by=3600), frequency=24)

# After here nans are created so we need to choose the non nan window.
start.time2 = as.POSIXlt("2018-01-05 00:00:00")
end.time2 = as.POSIXlt("2019-12-27 23:00:00")

trend <- read.table("../../RDN/Load Data (2018-2019)/artifacts/decomposition/rdn_trend.csv", sep=',', header=TRUE)
rownames(trend) <- 1:nrow(trend) 
trend <- trend[as.POSIXlt(trend$Date) >= start.time2,]
trend <- trend[as.POSIXlt(trend$Date) <= end.time2,]
y <- trend['trend']
trend_daily <- xts(y, seq(start.time, end.time, by=3600), frequency=24)

resid <- read.table("../../RDN/Load Data (2018-2019)/artifacts/decomposition/rdn_resid.csv", sep=',', header=TRUE)
rownames(resid) <- 1:nrow(resid) 
resid <- resid[as.POSIXlt(resid$Date) >= start.time2,]
resid <- resid[as.POSIXlt(resid$Date) <= end.time2,]
y <- resid['resid']
resid_daily <- xts(y, seq(start.time, end.time, by=3600), frequency=24)

# %% [markdown]
# ### Repeat plots for deseasonalised time series

# %%
j2 <- resid + trend
dj2 <- diff(j2)

# %%
options(repr.plot.width=20, repr.plot.height=20)
par(mfrow=c(2,2)) # set up the graphics
plot(j2,type="l", col='red', lwd=1,main="Time Series plot of Load", ylab="kwh")
hist(j2, nclass=25, main="Histogram of Load")
plot(dj2,type="l", col='red', lwd=1,main="Diff of Load", ylab="Log of kwh")
hist(dj2, nclass=25, main="Histogram of diff of Load")
# Out:
# Plot with title “Histogram of diff of Load”

# %%
par(mfrow=c(2,2)) # set up the graphics
acf(ts(j2, freq=1), 10*24, main="ACF of Total Active Load", na.action = na.pass) # autocorrelation function plot
pacf(ts(j2, freq=1), 10*24, main="PACF of Total Active Load", na.action = na.pass) # partial autocorrelation function
acf(ts(dj2, freq=1), 10*24, main="ACF of differences of log of Total Active Load", na.action = na.pass)
pacf(ts(dj2, freq=1), 10*24, main="PACF of differences of log of Total Active Load", na.action = na.pass)
# Out:
# Plot with title “PACF of differences of log of Total Active Load”

# %% [markdown]
# Not many things change with decomposition (strange)

# %% [markdown]
# ## Unit root testing

# %% [markdown]
# ### Drift

# %% [markdown]
# #### Original time series

# %%
m=ar(j)
m
m$order
m1=ur.df(j,type="drift",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = j)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  1.6463  -0.8481   0.2343  -0.3146   0.3996  -0.0323  -0.1091  -0.0035
#       9       10       11       12       13       14       15       16
# -0.1200   0.2337  -0.0940  -0.0373  -0.0532   0.0662  -0.0269   0.0008
#      17       18       19       20       21       22       23       24
#  0.0006   0.0174   0.0005   0.0158   0.0009  -0.0447   0.0754   0.7591
#      25       26       27       28       29       30       31       32
# -1.2933   0.6051  -0.1109   0.2287  -0.3416   0.0135   0.0915   0.0260
#      33       34       35       36       37       38       39       40
#  0.0694  -0.1618   0.0566   0.0562   0.0271  -0.0456  -0.0047   0.0232
#      41
# -0.0255
#
# Order selected 41  sigma^2 estimated as  132165
# [1] 41
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -14.606 106.67
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2741.5  -179.8    -4.2   167.6  3486.1
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.437e+02  3.051e+01  14.544  < 2e-16 ***
# z.lag.1      -1.919e-02  1.314e-03 -14.606  < 2e-16 ***
# z.diff.lag1   6.777e-01  7.542e-03  89.852  < 2e-16 ***
# z.diff.lag2  -2.000e-01  9.120e-03 -21.926  < 2e-16 ***
# z.diff.lag3   6.420e-02  9.243e-03   6.946 3.88e-12 ***
# z.diff.lag4  -2.723e-01  9.253e-03 -29.422  < 2e-16 ***
# z.diff.lag5   1.485e-01  9.480e-03  15.664  < 2e-16 ***
# z.diff.lag6   1.001e-01  9.541e-03  10.489  < 2e-16 ***
# z.diff.lag7  -6.465e-03  9.532e-03  -0.678 0.497644
# z.diff.lag8  -7.541e-04  9.523e-03  -0.079 0.936888
# z.diff.lag9  -1.342e-01  9.520e-03 -14.100  < 2e-16 ***
# z.diff.lag10  1.141e-01  9.569e-03  11.925  < 2e-16 ***
# z.diff.lag11  6.520e-03  9.560e-03   0.682 0.495268
# z.diff.lag12 -2.215e-02  9.485e-03  -2.335 0.019532 *
# z.diff.lag13 -8.454e-02  9.354e-03  -9.038  < 2e-16 ***
# z.diff.lag14 -1.100e-02  9.370e-03  -1.174 0.240300
# z.diff.lag15 -3.776e-02  9.340e-03  -4.043 5.30e-05 ***
# z.diff.lag16 -4.223e-02  8.379e-03  -5.040 4.70e-07 ***
# z.diff.lag17 -3.497e-02  5.975e-03  -5.852 4.95e-09 ***
# z.diff.lag18 -2.155e-02  5.981e-03  -3.604 0.000315 ***
# z.diff.lag19 -2.005e-02  5.964e-03  -3.363 0.000774 ***
# z.diff.lag20 -3.677e-03  5.963e-03  -0.617 0.537501
# z.diff.lag21 -5.804e-03  5.960e-03  -0.974 0.330198
# z.diff.lag22 -4.459e-02  5.953e-03  -7.490 7.20e-14 ***
# z.diff.lag23  2.168e-02  5.954e-03   3.641 0.000272 ***
# z.diff.lag24  7.968e-01  5.942e-03 134.090  < 2e-16 ***
# z.diff.lag25 -5.263e-01  8.456e-03 -62.247  < 2e-16 ***
# z.diff.lag26  1.183e-01  9.336e-03  12.668  < 2e-16 ***
# z.diff.lag27 -2.674e-02  9.375e-03  -2.852 0.004345 **
# z.diff.lag28  2.271e-01  9.345e-03  24.297  < 2e-16 ***
# z.diff.lag29 -1.376e-01  9.497e-03 -14.487  < 2e-16 ***
# z.diff.lag30 -1.090e-01  9.553e-03 -11.406  < 2e-16 ***
# z.diff.lag31 -1.832e-02  9.562e-03  -1.916 0.055389 .
# z.diff.lag32 -1.629e-03  9.495e-03  -0.172 0.863758
# z.diff.lag33  8.264e-02  9.492e-03   8.706  < 2e-16 ***
# z.diff.lag34 -9.728e-02  9.510e-03 -10.229  < 2e-16 ***
# z.diff.lag35 -2.481e-02  9.520e-03  -2.606 0.009167 **
# z.diff.lag36  2.113e-02  9.471e-03   2.232 0.025656 *
# z.diff.lag37  5.959e-02  9.210e-03   6.470 1.00e-10 ***
# z.diff.lag38  4.805e-03  9.215e-03   0.521 0.602087
# z.diff.lag39  2.112e-03  9.066e-03   0.233 0.815763
# z.diff.lag40  2.718e-02  7.565e-03   3.592 0.000329 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 356.1 on 17437 degrees of freedom
# Multiple R-squared:  0.9145,	Adjusted R-squared:  0.9143
# F-statistic:  4547 on 41 and 17437 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -14.606 106.67
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to drift.

# %% [markdown]
# ### Trend

# %% [markdown]
# #### Original time series

# %%
m=ar(j)
m
m$order
m1=ur.df(j,type="trend",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = j)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  1.6463  -0.8481   0.2343  -0.3146   0.3996  -0.0323  -0.1091  -0.0035
#       9       10       11       12       13       14       15       16
# -0.1200   0.2337  -0.0940  -0.0373  -0.0532   0.0662  -0.0269   0.0008
#      17       18       19       20       21       22       23       24
#  0.0006   0.0174   0.0005   0.0158   0.0009  -0.0447   0.0754   0.7591
#      25       26       27       28       29       30       31       32
# -1.2933   0.6051  -0.1109   0.2287  -0.3416   0.0135   0.0915   0.0260
#      33       34       35       36       37       38       39       40
#  0.0694  -0.1618   0.0566   0.0562   0.0271  -0.0456  -0.0047   0.0232
#      41
# -0.0255
#
# Order selected 41  sigma^2 estimated as  132165
# [1] 41
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -14.7946 72.9609 109.4396
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2733.3  -179.6    -4.2   168.1  3476.5
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.662e+02  3.198e+01  14.577  < 2e-16 ***
# z.lag.1      -1.969e-02  1.331e-03 -14.795  < 2e-16 ***
# tt           -1.266e-03  5.406e-04  -2.343 0.019160 *
# z.diff.lag1   6.779e-01  7.542e-03  89.883  < 2e-16 ***
# z.diff.lag2  -1.996e-01  9.121e-03 -21.882  < 2e-16 ***
# z.diff.lag3   6.453e-02  9.243e-03   6.981 3.03e-12 ***
# z.diff.lag4  -2.719e-01  9.253e-03 -29.383  < 2e-16 ***
# z.diff.lag5   1.488e-01  9.480e-03  15.694  < 2e-16 ***
# z.diff.lag6   1.004e-01  9.541e-03  10.521  < 2e-16 ***
# z.diff.lag7  -6.163e-03  9.532e-03  -0.647 0.517941
# z.diff.lag8  -4.317e-04  9.523e-03  -0.045 0.963840
# z.diff.lag9  -1.339e-01  9.520e-03 -14.068  < 2e-16 ***
# z.diff.lag10  1.144e-01  9.569e-03  11.952  < 2e-16 ***
# z.diff.lag11  6.766e-03  9.559e-03   0.708 0.479084
# z.diff.lag12 -2.195e-02  9.485e-03  -2.314 0.020672 *
# z.diff.lag13 -8.429e-02  9.354e-03  -9.011  < 2e-16 ***
# z.diff.lag14 -1.079e-02  9.369e-03  -1.152 0.249509
# z.diff.lag15 -3.753e-02  9.340e-03  -4.018 5.90e-05 ***
# z.diff.lag16 -4.216e-02  8.378e-03  -5.032 4.89e-07 ***
# z.diff.lag17 -3.468e-02  5.976e-03  -5.804 6.58e-09 ***
# z.diff.lag18 -2.128e-02  5.981e-03  -3.558 0.000375 ***
# z.diff.lag19 -1.981e-02  5.964e-03  -3.321 0.000898 ***
# z.diff.lag20 -3.443e-03  5.963e-03  -0.577 0.563694
# z.diff.lag21 -5.580e-03  5.960e-03  -0.936 0.349202
# z.diff.lag22 -4.438e-02  5.953e-03  -7.455 9.42e-14 ***
# z.diff.lag23  2.186e-02  5.954e-03   3.672 0.000241 ***
# z.diff.lag24  7.969e-01  5.942e-03 134.126  < 2e-16 ***
# z.diff.lag25 -5.259e-01  8.456e-03 -62.194  < 2e-16 ***
# z.diff.lag26  1.185e-01  9.335e-03  12.692  < 2e-16 ***
# z.diff.lag27 -2.649e-02  9.374e-03  -2.825 0.004726 **
# z.diff.lag28  2.273e-01  9.345e-03  24.322  < 2e-16 ***
# z.diff.lag29 -1.373e-01  9.497e-03 -14.460  < 2e-16 ***
# z.diff.lag30 -1.087e-01  9.553e-03 -11.384  < 2e-16 ***
# z.diff.lag31 -1.811e-02  9.561e-03  -1.894 0.058268 .
# z.diff.lag32 -1.471e-03  9.494e-03  -0.155 0.876842
# z.diff.lag33  8.280e-02  9.491e-03   8.724  < 2e-16 ***
# z.diff.lag34 -9.710e-02  9.510e-03 -10.211  < 2e-16 ***
# z.diff.lag35 -2.463e-02  9.519e-03  -2.588 0.009666 **
# z.diff.lag36  2.134e-02  9.470e-03   2.253 0.024256 *
# z.diff.lag37  5.972e-02  9.209e-03   6.485 9.13e-11 ***
# z.diff.lag38  4.965e-03  9.214e-03   0.539 0.590010
# z.diff.lag39  2.211e-03  9.065e-03   0.244 0.807338
# z.diff.lag40  2.746e-02  7.565e-03   3.630 0.000284 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 356.1 on 17436 degrees of freedom
# Multiple R-squared:  0.9145,	Adjusted R-squared:  0.9143
# F-statistic:  4440 on 42 and 17436 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -14.7946 72.9609 109.4396
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to trend.

# %% [markdown]
# ## Normality tests

# %%
shapiro.test(sample(coredata(j), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(j, prob=TRUE, 15) # histogram
lines(density(j)) # smooth it - ?density for details
qqnorm(j,main="Normal QQplot of timeseries") # normal Q-Q plot
qqline(j)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(j), 5000, replace = FALSE)
# W = 0.97486, p-value < 2.2e-16
# Plot with title “Normal QQplot of timeseries”

# %% [markdown]
# Null hypothesis for normality is rejected in all cases according to the Shapiro tests and qqplots. So we will need to consider the BoxCox transformation in the training process.

# %% [markdown]
# ### Box Cox transform
# A sample Box Cox transformation

# %%
normalised=BoxCox(j, 0.55)
shapiro.test(sample(coredata(normalised), 5000, replace=FALSE))
par(mfrow=c(2,1))
hist(normalised, prob=TRUE, 15) # histogram
lines(density(tsclean(normalised))) # smooth it - ?density for details
qqnorm(tsclean(normalised), main="Normal QQplot of diff log timeseries") # normal Q-Q plot
qqline(normalised)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(normalised), 5000, replace = FALSE)
# W = 0.97894, p-value < 2.2e-16
# Plot with title “Normal QQplot of diff log timeseries”

# %% [markdown]
# The box cox transform is not effective at all.

# %%
ltrain = j['/2019-11-30 23:00:00']
ltest = j['2021-12-01 00:00:00/']

# %% [markdown]
# ### tbats

# %% [markdown]
# Seasonal periods: 24 (daily), 7*24 (weekly), 365*24 (yearly).

# %%
tb <- tbats(tsclean(ltrain), use.box.cox=TRUE, use.trend=TRUE,
            seasonal.periods=c(24, 25, 7*24, 365*24), use.arma.errors=TRUE, 
            use.parallel=TRUE, num.cores=6, biasadj=TRUE)
tb
# Out:
# BATS(0.397, {2,2}, 0.811, -)
#
# Call: tbats(y = tsclean(ltrain), use.box.cox = TRUE, use.trend = TRUE,
#     seasonal.periods = c(24, 25, 7 * 24, 365 * 24), use.arma.errors = TRUE,
#     use.parallel = TRUE, num.cores = 6, biasadj = TRUE)
#
# Parameters
#   Lambda: 0.397249
#   Alpha: 1.685696
#   Beta: -0.3804002
#   Damping Parameter: 0.810504
#   AR coefficients: 1.483752 -0.652405
#   MA coefficients: -0.932767 0.283981
#
# Seed States:
#             [,1]
# [1,] 109.3838399
# [2,]   0.6509441
# [3,]   0.0000000
# [4,]   0.0000000
# [5,]   0.0000000
# [6,]   0.0000000
# attr(,"lambda")
# [1] 0.3972491
#
# Sigma: 1.663675
# AIC: 383170.2

# %%
acf(resid(tb), lag.max = 100)
pacf(resid(tb), lag.max=100)
# Out:
# Plot with title “Series  resid(tb)”
# Plot with title “Series  resid(tb)”

# %% [markdown]
# Tbats retains some systematic patterns in residuals. Rejected.

# %% [markdown]
# ### ARIMA and SARIMA
# ACF and PACF is plotted again in order to have a look at the possible ar, ma and respective seasonal (sma, sar) terms.

# %%
acf(tsclean(dj))
pacf(tsclean(dj))
# Out:
# Plot with title “Series  tsclean(dj)”
# Plot with title “Series  tsclean(dj)”

# %% [markdown]
# Most probable models based on the ACF and PACF are ma(4), ar(2) or ar(4), sma(24, 48, ...), sar(24, 48, ...) along with a differentiation term.

# %% [markdown]
# auto.arima is trained on the time series

# %%
auto <- auto.arima(ltrain)
summary(auto)
# Out:
# Series: ltrain
# ARIMA(4,1,3)
#
# Coefficients:
#          ar1     ar2     ar3      ar4     ma1      ma2      ma3
#       0.2819  0.6472  0.4264  -0.7075  0.5449  -0.5107  -0.9184
# s.e.  0.0065  0.0068  0.0064   0.0062  0.0054   0.0066   0.0049
#
# sigma^2 estimated as 509090:  log likelihood=-134016
# AIC=268048.1   AICc=268048.1   BIC=268109.9
#
# Training set error measures:
#                     ME     RMSE      MAE         MPE     MAPE       MASE
# Training set 0.9859096 713.3352 532.3284 -0.08140085 2.269948 0.02307257
#                    ACF1
# Training set 0.08851115

# %% [markdown]
# An extended summary is also provided using the sarima function of astsa package.

# %%
sarima(j, 4, 1, 3, 0, 0, 0)
# Out:
# initial  value 7.103434
# iter   2 value 6.867202
# iter   3 value 6.813822
# iter   4 value 6.692782
# iter   5 value 6.643132
# iter   6 value 6.632572
# iter   7 value 6.627141
# iter   8 value 6.626341
# iter   9 value 6.624427
# iter  10 value 6.623300
# iter  11 value 6.622660
# iter  12 value 6.620876
# iter  13 value 6.608302
# iter  14 value 6.602687
# iter  15 value 6.600112
# iter  16 value 6.594916
# iter  17 value 6.587346
# iter  18 value 6.584335
# iter  19 value 6.579823
# iter  20 value 6.577128
# iter  21 value 6.573599
# iter  22 value 6.570814
# iter  23 value 6.568865
# iter  24 value 6.567349
# iter  25 value 6.567100
# iter  26 value 6.566946
# iter  27 value 6.566848
# iter  28 value 6.566820
# iter  29 value 6.566820
# iter  29 value 6.566820
# iter  29 value 6.566820
# final  value 6.566820
# converged
# initial  value 6.566572
# iter   2 value 6.566568
# iter   3 value 6.566566
# iter   4 value 6.566565
# iter   5 value 6.566562
# iter   6 value 6.566561
# iter   7 value 6.566561
# iter   7 value 6.566561
# iter   7 value 6.566561
# final  value 6.566561
# converged
# $fit
#
# Call:
# arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D, Q), period = S),
#     xreg = constant, transform.pars = trans, fixed = fixed, optim.control = list(trace = trc,
#         REPORT = 1, reltol = tol))
#
# Coefficients:
#          ar1     ar2     ar3      ar4     ma1      ma2      ma3  constant
#       0.2874  0.6468  0.4247  -0.7116  0.5456  -0.5089  -0.9166    0.1512
# s.e.  0.0063  0.0066  0.0063   0.0061  0.0051   0.0061   0.0046    1.8322
#
# sigma^2 estimated as 505298:  log likelihood = -139898,  aic = 279813.9
#
# $degrees_of_freedom
# [1] 17511
#
# $ttable
#          Estimate     SE   t.value p.value
# ar1        0.2874 0.0063   45.3013  0.0000
# ar2        0.6468 0.0066   98.4788  0.0000
# ar3        0.4247 0.0063   67.5776  0.0000
# ar4       -0.7116 0.0061 -117.4754  0.0000
# ma1        0.5456 0.0051  107.1931  0.0000
# ma2       -0.5089 0.0061  -82.9375  0.0000
# ma3       -0.9166 0.0046 -197.8641  0.0000
# constant   0.1512 1.8322    0.0825  0.9342
#
# $AIC
# [1] 15.97203
#
# $AICc
# [1] 15.97203
#
# $BIC
# [1] 15.97602
# Plot with title “p values for Ljung-Box statistic”

# %% [markdown]
# The model seems to ignore seasonal terms. It also produces systematic residuals. Therfore we proceed to further inspection with gridsearch...

# %%
d=1
DD=1
per=24

aics <- c()
c <- 0

for(p in 5:1){
  for(q in 2:1){
    for(i in 5:1){
      for(k in 5:1){
        for(d in 2:1){
            if(p+d+q+i+DD+k<=20){
                c <- c + 1
                tryCatch({
                    model <- arima(x=j, order=c((p-1),d,(q-1)), 
                                 seasonal=list(order=c((i-1),DD,(k-1)), 
                                 period=per))
                    pval <- Box.test(model$residuals, lag=log(length(model$residuals)))
                    sse <- sum(model$residuals^2)
                    cat(c, ". ", p-1,d,q-1,i-1,DD,k-1,per, 'AIC=', model$aic, ', SSE=',sse,', Residual correlation p-VALUE=', pval$p.value,'\n')
                    aics <- c(aics, model$aic)

                  }, error = function(e) {
                        cat(c, ". ", p-1,d,q-1,i-1,DD,k-1,per, 'Failed!\n')
                        aics <- c(aics, 1000000000)
                })

            }
        }
      }
    }
  }
}
cat('Minimum AIC: ', min(aics), "\nModel id: ", which.min(aics))
# Out:
# 1 .  4 2 1 4 1 4 24 Failed!
# 2 .  4 1 1 4 1 4 24 Failed!
# 3 .  4 2 1 4 1 3 24 Failed!
# 4 .  4 1 1 4 1 3 24 Failed!
# 5 .  4 2 1 4 1 2 24 Failed!
# 6 .  4 1 1 4 1 2 24 Failed!
# 7 .  4 2 1 4 1 1 24 Failed!
# 8 .  4 1 1 4 1 1 24 AIC= 252292.9 , SSE= 1870819838 , Residual correlation p-VALUE= 0
# 9 .  4 2 1 4 1 0 24 AIC= 255937.7 , SSE= 2308071703 , Residual correlation p-VALUE= 0
# 10 .  4 1 1 4 1 0 24 AIC= 255007.3 , SSE= 2187407968 , Residual correlation p-VALUE= 0
# 11 .  4 2 1 3 1 4 24 Failed!
# 12 .  4 1 1 3 1 4 24 AIC= 252267.7 , SSE= 1867288124 , Residual correlation p-VALUE= 0
# 13 .  4 2 1 3 1 3 24 Failed!
# 14 .  4 1 1 3 1 3 24 AIC= 251808 , SSE= 1818989021 , Residual correlation p-VALUE= 0
# 15 .  4 2 1 3 1 2 24 AIC= 253377.3 , SSE= 1990900049 , Residual correlation p-VALUE= 0
# 16 .  4 1 1 3 1 2 24 AIC= 253136.1 , SSE= 1963988139 , Residual correlation p-VALUE= 0
# 17 .  4 2 1 3 1 1 24 AIC= 253355 , SSE= 1988553236 , Residual correlation p-VALUE= 0
# 18 .  4 1 1 3 1 1 24 AIC= 253070.2 , SSE= 1956733070 , Residual correlation p-VALUE= 0
# 19 .  4 2 1 3 1 0 24 AIC= 256523.3 , SSE= 2387359074 , Residual correlation p-VALUE= 0
# 20 .  4 1 1 3 1 0 24 AIC= 255524.4 , SSE= 2253646124 , Residual correlation p-VALUE= 0
# 21 .  4 2 1 2 1 4 24 Failed!
# 22 .  4 1 1 2 1 4 24 AIC= 252399.2 , SSE= 1881943062 , Residual correlation p-VALUE= 0
# 23 .  4 2 1 2 1 3 24 AIC= 252541.1 , SSE= 1895765658 , Residual correlation p-VALUE= 0
# Warning message in log(s2):
# “NaNs produced”

# %% [markdown]
# #### Extensive residual summary of the best model:

# %%
sarima(j, 4, 1, 3, 2, 1, 3, 24)

# %% [markdown]
# Residuals still demonstrate systematic patterns while their variance seems to have some volatility especially at the sides of the diagram. Furthermore p-values are marginal that is a bit higher than 0.05. In any case this is the best arima model and will be used for forecasting as well. The auto.arima selected model is ignored (despite of the lower AIC value) as it is clear from the residual ACF that correlations are much bigger than the almost insignificant ones of this particular seasonal model.

# %% [markdown]
# # Final observations
# 1. We need to take into account that despite the yearly seasonality we do not posess data of a whole year and therefore we cannot model this pattern. This seems to somehow confuse the models.
# 2. Best sarima model is used in python to produce forecasts and evaluate them.
