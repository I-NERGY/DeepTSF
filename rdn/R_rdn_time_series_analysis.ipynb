# %%
library(forecast)
library(urca)
library(tseries)
library(zoo)
library(xts)
library(repr)
library(dplyr)
library(ggfortify)
library(astsa)

# %% [markdown]
# # Load data

# %%
data <- read.table("../../RDN/Load Data (2018-2019)/artifacts/timeseries_60min.csv", sep=',', header=TRUE)
y <- data['Load']

# %% [markdown]
# # Create time series

# %%
start.time <- as.POSIXlt("2018-01-01 00:00:00")
tsdat <- xts(y, seq(start.time, start.time + 20907000, by=3600), frequency=24)

print("Univariate time series created:")
head(as.matrix(tsdat))
# Out:
# [1] "Univariate time series created:"
#                     Diff.Load.Activa.Total..60.minuto.
# 2020-11-01 00:00:00 NA
# 2020-11-01 01:00:00 NA
# 2020-11-01 01:00:00 NA
# 2020-11-01 02:00:00 NA
# 2020-11-01 03:00:00 NA
# 2020-11-01 04:00:00 NA

# %% [markdown]
# # Clean initial zeros
# Initial 5 days zero values are cleaned as they are due to lack of mesurements.

# %%
j <- tsdat['2020-11-06 11:00:00/']
head(as.matrix(j))
j[is.na(j)]
# Out:
#                     Diff.Load.Activa.Total..60.minuto.
# 2020-11-06 11:00:00 3670
# 2020-11-06 12:00:00 4240
# 2020-11-06 13:00:00 3810
# 2020-11-06 14:00:00 3800
# 2020-11-06 15:00:00 3820
# 2020-11-06 16:00:00 3770
#      Diff.Load.Activa.Total..60.minuto.

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Time series plot

# %%
options(repr.plot.width=20, repr.plot.height=6)
plot(j, type="l", col='red', lwd=0.5, main="Total Active Energy", ylab="kwh")
# Out:
# plot without title

# %% [markdown]
# ## Outlier handling

# %% [markdown]
# 2 methods are used to detect outliers (forecast package):
# 1. tsclean which implements loess decomposition of time series to identify and replace outliers
# 2. tsoutliers function which implements the Chen and Liu method
# Results are exactly the same for both. No outliers are detected at all.

# %%
setdiff(tsclean(j)$Diff.Load.Activa.Total..60.minuto., j$Diff.Load.Activa.Total..60.minuto.)
# Out:
# numeric(0)

# %%
tsoutliers(j)
# Out:
# $index
# integer(0)
#
# $replacements
#      Diff.Load.Activa.Total..60.minuto.

# %% [markdown]
# ## Transforms

# %%
dj=diff(j)
lj = log(j)

# %%
options(repr.plot.width=20, repr.plot.height=15)
par(mfrow=c(3,2)) # set up the graphics
plot(j,type="l", col='red', lwd=1,main="Time Series plot of Total Active Energy", ylab="kwh")
hist(j, nclass=25, main="Histogram of Total Active Energy")
plot(lj,type="l", col='red', lwd=1,main="Differences of log of Total Active Energy")
hist(lj, nclass=25, main="Histogram of differences of log of Total Active Energy")
plot(dj,type="l", col='red', lwd=1,main="Log of Total Active Energy", ylab="Log of kwh")
hist(dj, nclass=25, main="Histogram of log of Total Active Energy")
# Out:
# Plot with title “Histogram of log of Total Active Energy”

# %%
par(mfrow=c(2,2)) # set up the graphics
acf(ts(j, freq=1), 100, main="ACF of Total Active Load") # autocorrelation function plot
pacf(ts(j, freq=1), 100, main="PACF of Total Active Energy") # partial autocorrelation function
acf(ts(dj, freq=1), 100, main="ACF of differences of Total Active Energy", na.action = na.pass)
pacf(ts(dj, freq=1), 100, main="PACF of differences of Total Active Energy", na.action = na.pass)
# Out:
# Plot with title “PACF of differences of Total Active Energy”

# %% [markdown]
# It is observed that following the diff transformations the time series seems much closer to stationary, effectively removing the trend. This demonstrated the need for on differentiation term. Also skewness of the distribution is mitigated. Heteroskedasticity still appears even in the log transformation and therefore it wont be used further. Seasonal patterns are also observed leading to exploration of decomposition.

# %% [markdown]
# ## Decomposition
# The time series obviously seems to require decomposition

# %%
start.time <- as.POSIXlt("2020-11-06 00:00:00")

seasonal <- read.table("../VEOLIA/artifacts/decomposition/TAL_seasonal.csv", sep=',', header=TRUE)
y <- seasonal['seasonal']
seasonal <- xts(y, seq(start.time, start.time + 20475000, by=3600), frequency=24)

trend <- read.table("../VEOLIA/artifacts/decomposition/TAL_trend.csv", sep=',', header=TRUE)
y <- trend['trend']
trend <- xts(y, seq(start.time, start.time + 20475000, by=3600), frequency=24)

resid <- read.table("../VEOLIA/artifacts/decomposition/TAL_resid.csv", sep=',', header=TRUE)
y <- resid['Diff.Load.Activa.Total..60.minuto.']
resid <- xts(y, seq(start.time, start.time + 20475000, by=3600), frequency=24)

# %% [markdown]
# ### Repeat plots for deseasonalised time series

# %%
j2 <- resid + trend
dj2 <- diff(j2)

# %%
options(repr.plot.width=20, repr.plot.height=20)
par(mfrow=c(2,2)) # set up the graphics
plot(j2,type="l", col='red', lwd=1,main="Time Series plot of Total Active Energy", ylab="kwh")
hist(j2, nclass=25, main="Histogram of Total Active Energy")
plot(dj2,type="l", col='red', lwd=1,main="Diff of Total Active Energy", ylab="Log of kwh")
hist(dj2, nclass=25, main="Histogram of diff of Total Active Energy")
# Out:
# Plot with title “Histogram of diff of Total Active Energy”

# %%
par(mfrow=c(2,2)) # set up the graphics
acf(ts(j2, freq=1), 100, main="ACF of Total Active Load", na.action = na.pass) # autocorrelation function plot
pacf(ts(j2, freq=1), 100, main="PACF of Total Active Load", na.action = na.pass) # partial autocorrelation function
acf(ts(dj2, freq=1), 100, main="ACF of differences of log of Total Active Load", na.action = na.pass)
pacf(ts(dj2, freq=1), 100, main="PACF of differences of log of Total Active Load", na.action = na.pass)
# Out:
# Plot with title “PACF of differences of log of Total Active Load”

# %% [markdown]
# Not many things change with decomposition (strange)

# %% [markdown]
# ## Unit root testing

# %% [markdown]
# ### Drift

# %% [markdown]
# #### Original time series

# %%
m=ar(tsclean(j))
m
m$order
m1=ur.df(tsclean(j),type="drift",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = tsclean(j))
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  0.4757   0.0979   0.1168  -0.0526   0.0190   0.0488   0.0287  -0.0385
#       9       10       11       12       13       14       15       16
#  0.0310  -0.0054   0.0153  -0.0081  -0.0075  -0.0052  -0.0286  -0.0117
#      17       18       19       20       21       22       23       24
#  0.0231   0.0422   0.0220   0.0272   0.0014   0.0326   0.1029   0.2082
#      25       26       27       28       29       30       31       32
# -0.0147  -0.0476  -0.0389   0.0061   0.0032  -0.0228  -0.0220  -0.0369
#
# Order selected 32  sigma^2 estimated as  84222
# [1] 32
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -3.793 7.2403
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1515.45  -128.79     6.31   134.40  1746.80
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  99.275543  26.763752   3.709  0.00021 ***
# z.lag.1      -0.035673   0.009405  -3.793  0.00015 ***
# z.diff.lag1  -0.495612   0.015945 -31.083  < 2e-16 ***
# z.diff.lag2  -0.398788   0.017264 -23.099  < 2e-16 ***
# z.diff.lag3  -0.282942   0.018057 -15.670  < 2e-16 ***
# z.diff.lag4  -0.335978   0.018440 -18.220  < 2e-16 ***
# z.diff.lag5  -0.317088   0.018972 -16.714  < 2e-16 ***
# z.diff.lag6  -0.267898   0.019414 -13.799  < 2e-16 ***
# z.diff.lag7  -0.238916   0.019677 -12.142  < 2e-16 ***
# z.diff.lag8  -0.276943   0.019853 -13.949  < 2e-16 ***
# z.diff.lag9  -0.245037   0.020168 -12.150  < 2e-16 ***
# z.diff.lag10 -0.249195   0.020289 -12.283  < 2e-16 ***
# z.diff.lag11 -0.233470   0.020358 -11.468  < 2e-16 ***
# z.diff.lag12 -0.241434   0.020388 -11.842  < 2e-16 ***
# z.diff.lag13 -0.249255   0.020382 -12.229  < 2e-16 ***
# z.diff.lag14 -0.253272   0.020340 -12.452  < 2e-16 ***
# z.diff.lag15 -0.281827   0.020196 -13.954  < 2e-16 ***
# z.diff.lag16 -0.294493   0.020058 -14.682  < 2e-16 ***
# z.diff.lag17 -0.271526   0.019986 -13.586  < 2e-16 ***
# z.diff.lag18 -0.228803   0.019933 -11.479  < 2e-16 ***
# z.diff.lag19 -0.206545   0.019798 -10.432  < 2e-16 ***
# z.diff.lag20 -0.178682   0.019639  -9.098  < 2e-16 ***
# z.diff.lag21 -0.176236   0.019442  -9.065  < 2e-16 ***
# z.diff.lag22 -0.142894   0.019200  -7.442 1.14e-13 ***
# z.diff.lag23 -0.039650   0.018922  -2.095  0.03617 *
# z.diff.lag24  0.169750   0.018463   9.194  < 2e-16 ***
# z.diff.lag25  0.157210   0.018233   8.622  < 2e-16 ***
# z.diff.lag26  0.111448   0.017898   6.227 5.10e-10 ***
# z.diff.lag27  0.073669   0.017337   4.249 2.18e-05 ***
# z.diff.lag28  0.080146   0.016644   4.815 1.51e-06 ***
# z.diff.lag29  0.083710   0.016121   5.193 2.15e-07 ***
# z.diff.lag30  0.060773   0.015089   4.028 5.71e-05 ***
# z.diff.lag31  0.038699   0.013358   2.897  0.00378 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 289.6 on 5611 degrees of freedom
# Multiple R-squared:  0.3031,	Adjusted R-squared:  0.2991
# F-statistic: 76.25 on 32 and 5611 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -3.793 7.2403
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# #### Diff time series

# %%
m=ar(tsclean(dj))
m
m$order
m1=ur.df(tsclean(dj),type="drift",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = tsclean(dj))
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  0.0356  -0.0416   0.0046  -0.0271  -0.0125   0.0236   0.0055  -0.0172
#       9       10       11       12       13       14       15       16
#  0.0101  -0.0282  -0.0021  -0.0035  -0.0214  -0.0067  -0.0285  -0.0238
#      17       18       19       20       21       22       23       24
# -0.0016   0.0091   0.0207   0.0012  -0.0052   0.0031   0.0733   0.1297
#      25       26       27       28       29       30       31       32
#  0.0301   0.0174  -0.0233   0.0056  -0.0049  -0.0089  -0.0234  -0.0312
#      33
# -0.0234
#
# Order selected 33  sigma^2 estimated as  48629
# [1] 33
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -12.4211 77.1426
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -741.87  -94.15   10.85   94.10  733.88
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -21.440048   3.401322  -6.303 3.13e-10 ***
# z.lag.1       -0.961154   0.077381 -12.421  < 2e-16 ***
# z.diff.lag1   -0.004686   0.076364  -0.061 0.951067
# z.diff.lag2   -0.045177   0.075406  -0.599 0.549115
# z.diff.lag3   -0.040845   0.074489  -0.548 0.583480
# z.diff.lag4   -0.068218   0.073583  -0.927 0.353918
# z.diff.lag5   -0.080921   0.072675  -1.113 0.265558
# z.diff.lag6   -0.056872   0.071744  -0.793 0.427984
# z.diff.lag7   -0.050962   0.070852  -0.719 0.472007
# z.diff.lag8   -0.069039   0.069913  -0.987 0.323443
# z.diff.lag9   -0.058142   0.068886  -0.844 0.398687
# z.diff.lag10  -0.084400   0.067505  -1.250 0.211248
# z.diff.lag11  -0.085908   0.065892  -1.304 0.192366
# z.diff.lag12  -0.089810   0.064229  -1.398 0.162085
# z.diff.lag13  -0.111560   0.062533  -1.784 0.074476 .
# z.diff.lag14  -0.117484   0.060790  -1.933 0.053334 .
# z.diff.lag15  -0.145343   0.058924  -2.467 0.013670 *
# z.diff.lag16  -0.169823   0.056978  -2.980 0.002890 **
# z.diff.lag17  -0.171658   0.054984  -3.122 0.001806 **
# z.diff.lag18  -0.162073   0.053006  -3.058 0.002242 **
# z.diff.lag19  -0.140922   0.051052  -2.760 0.005792 **
# z.diff.lag20  -0.139342   0.049033  -2.842 0.004502 **
# z.diff.lag21  -0.144613   0.047011  -3.076 0.002107 **
# z.diff.lag22  -0.141179   0.044912  -3.143 0.001678 **
# z.diff.lag23  -0.066783   0.042710  -1.564 0.117960
# z.diff.lag24   0.063317   0.040485   1.564 0.117880
# z.diff.lag25   0.093272   0.038082   2.449 0.014345 *
# z.diff.lag26   0.110824   0.035614   3.112 0.001869 **
# z.diff.lag27   0.087441   0.032931   2.655 0.007947 **
# z.diff.lag28   0.093172   0.029855   3.121 0.001812 **
# z.diff.lag29   0.088392   0.026520   3.333 0.000865 ***
# z.diff.lag30   0.079271   0.022918   3.459 0.000546 ***
# z.diff.lag31   0.055418   0.018570   2.984 0.002854 **
# z.diff.lag32   0.023867   0.013369   1.785 0.074270 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 220.5 on 5609 degrees of freedom
# Multiple R-squared:  0.493,	Adjusted R-squared:   0.49
# F-statistic: 165.3 on 33 and 5609 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -12.4211 77.1426
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to drift.

# %% [markdown]
# ### Trend

# %% [markdown]
# #### Original time series

# %%
m=ar(j)
m
m$order
m1=ur.df(j,type="trend",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = j)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  0.4757   0.0979   0.1168  -0.0526   0.0190   0.0488   0.0287  -0.0385
#       9       10       11       12       13       14       15       16
#  0.0310  -0.0054   0.0153  -0.0081  -0.0075  -0.0052  -0.0286  -0.0117
#      17       18       19       20       21       22       23       24
#  0.0231   0.0422   0.0220   0.0272   0.0014   0.0326   0.1029   0.2082
#      25       26       27       28       29       30       31       32
# -0.0147  -0.0476  -0.0389   0.0061   0.0032  -0.0228  -0.0220  -0.0369
#
# Order selected 32  sigma^2 estimated as  84222
# [1] 32
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -5.4395 9.9112 14.8198
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1507.68  -129.81     6.75   135.06  1737.56
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  232.987746  43.468053   5.360 8.66e-08 ***
# z.lag.1       -0.070303   0.012924  -5.440 5.57e-08 ***
# tt            -0.012684   0.003252  -3.901 9.70e-05 ***
# z.diff.lag1   -0.463595   0.017916 -25.877  < 2e-16 ***
# z.diff.lag2   -0.368067   0.018956 -19.417  < 2e-16 ***
# z.diff.lag3   -0.253190   0.019581 -12.931  < 2e-16 ***
# z.diff.lag4   -0.306891   0.019869 -15.446  < 2e-16 ***
# z.diff.lag5   -0.288816   0.020287 -14.237  < 2e-16 ***
# z.diff.lag6   -0.240301   0.020640 -11.643  < 2e-16 ***
# z.diff.lag7   -0.211763   0.020848 -10.157  < 2e-16 ***
# z.diff.lag8   -0.250127   0.020986 -11.919  < 2e-16 ***
# z.diff.lag9   -0.219159   0.021207 -10.334  < 2e-16 ***
# z.diff.lag10  -0.224437   0.021234 -10.570  < 2e-16 ***
# z.diff.lag11  -0.209920   0.021209  -9.898  < 2e-16 ***
# z.diff.lag12  -0.219043   0.021156 -10.354  < 2e-16 ***
# z.diff.lag13  -0.228134   0.021064 -10.830  < 2e-16 ***
# z.diff.lag14  -0.233476   0.020939 -11.151  < 2e-16 ***
# z.diff.lag15  -0.263479   0.020712 -12.721  < 2e-16 ***
# z.diff.lag16  -0.277735   0.020488 -13.556  < 2e-16 ***
# z.diff.lag17  -0.256362   0.020336 -12.606  < 2e-16 ***
# z.diff.lag18  -0.215105   0.020215 -10.641  < 2e-16 ***
# z.diff.lag19  -0.194177   0.020026  -9.696  < 2e-16 ***
# z.diff.lag20  -0.167559   0.019820  -8.454  < 2e-16 ***
# z.diff.lag21  -0.166244   0.019586  -8.488  < 2e-16 ***
# z.diff.lag22  -0.134064   0.019309  -6.943 4.27e-12 ***
# z.diff.lag23  -0.031899   0.019002  -1.679  0.09327 .
# z.diff.lag24   0.176621   0.018524   9.535  < 2e-16 ***
# z.diff.lag25   0.163866   0.018290   8.959  < 2e-16 ***
# z.diff.lag26   0.117783   0.017949   6.562 5.78e-11 ***
# z.diff.lag27   0.079424   0.017378   4.570 4.97e-06 ***
# z.diff.lag28   0.085172   0.016672   5.109 3.35e-07 ***
# z.diff.lag29   0.088160   0.016141   5.462 4.91e-08 ***
# z.diff.lag30   0.064375   0.015099   4.264 2.04e-05 ***
# z.diff.lag31   0.041128   0.013356   3.079  0.00208 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 289.2 on 5610 degrees of freedom
# Multiple R-squared:  0.3049,	Adjusted R-squared:  0.3009
# F-statistic: 74.58 on 33 and 5610 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -5.4395 9.9112 14.8198
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %% [markdown]
# #### Diff time series

# %%
m=ar(tsclean(dj))
m
m$order
m1=ur.df(tsclean(dj),type="trend",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = tsclean(dj))
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  0.0356  -0.0416   0.0046  -0.0271  -0.0125   0.0236   0.0055  -0.0172
#       9       10       11       12       13       14       15       16
#  0.0101  -0.0282  -0.0021  -0.0035  -0.0214  -0.0067  -0.0285  -0.0238
#      17       18       19       20       21       22       23       24
# -0.0016   0.0091   0.0207   0.0012  -0.0052   0.0031   0.0733   0.1297
#      25       26       27       28       29       30       31       32
#  0.0301   0.0174  -0.0233   0.0056  -0.0049  -0.0089  -0.0234  -0.0312
#      33
# -0.0234
#
# Order selected 33  sigma^2 estimated as  48629
# [1] 33
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -12.4364 51.5553 77.3323
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -739.38  -94.00   10.60   94.42  730.97
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -18.246690   6.101297  -2.991 0.002796 **
# z.lag.1       -0.963574   0.077480 -12.436  < 2e-16 ***
# tt            -0.001138   0.001805  -0.630 0.528420
# z.diff.lag1   -0.002337   0.076459  -0.031 0.975616
# z.diff.lag2   -0.042900   0.075496  -0.568 0.569900
# z.diff.lag3   -0.038641   0.074575  -0.518 0.604378
# z.diff.lag4   -0.066090   0.073664  -0.897 0.369661
# z.diff.lag5   -0.078868   0.072752  -1.084 0.278382
# z.diff.lag6   -0.054893   0.071816  -0.764 0.444692
# z.diff.lag7   -0.049059   0.070920  -0.692 0.489122
# z.diff.lag8   -0.067216   0.069977  -0.961 0.336821
# z.diff.lag9   -0.056397   0.068945  -0.818 0.413391
# z.diff.lag10  -0.082739   0.067560  -1.225 0.220748
# z.diff.lag11  -0.084339   0.065942  -1.279 0.200957
# z.diff.lag12  -0.088334   0.064275  -1.374 0.169400
# z.diff.lag13  -0.110175   0.062575  -1.761 0.078349 .
# z.diff.lag14  -0.116185   0.060828  -1.910 0.056177 .
# z.diff.lag15  -0.144127   0.058959  -2.445 0.014535 *
# z.diff.lag16  -0.168693   0.057010  -2.959 0.003099 **
# z.diff.lag17  -0.170617   0.055012  -3.101 0.001935 **
# z.diff.lag18  -0.161119   0.053030  -3.038 0.002391 **
# z.diff.lag19  -0.140053   0.051073  -2.742 0.006122 **
# z.diff.lag20  -0.138558   0.049051  -2.825 0.004748 **
# z.diff.lag21  -0.143911   0.047027  -3.060 0.002222 **
# z.diff.lag22  -0.140556   0.044925  -3.129 0.001765 **
# z.diff.lag23  -0.066231   0.042721  -1.550 0.121125
# z.diff.lag24   0.063804   0.040494   1.576 0.115168
# z.diff.lag25   0.093704   0.038090   2.460 0.013921 *
# z.diff.lag26   0.111205   0.035621   3.122 0.001806 **
# z.diff.lag27   0.087773   0.032937   2.665 0.007724 **
# z.diff.lag28   0.093450   0.029859   3.130 0.001759 **
# z.diff.lag29   0.088616   0.026523   3.341 0.000840 ***
# z.diff.lag30   0.079438   0.022921   3.466 0.000533 ***
# z.diff.lag31   0.055535   0.018571   2.990 0.002799 **
# z.diff.lag32   0.023932   0.013370   1.790 0.073515 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 220.6 on 5608 degrees of freedom
# Multiple R-squared:  0.493,	Adjusted R-squared:   0.49
# F-statistic: 160.4 on 34 and 5608 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -12.4364 51.5553 77.3323
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to trend.

# %% [markdown]
# ## Normality tests

# %%
shapiro.test(sample(coredata(j), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(j, prob=TRUE, 15) # histogram
lines(density(j)) # smooth it - ?density for details
qqnorm(j,main="Normal QQplot of timeseries") # normal Q-Q plot
qqline(j)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(j), 5000, replace = FALSE)
# W = 0.98638, p-value < 2.2e-16
# Plot with title “Normal QQplot of timeseries”

# %%
shapiro.test(sample(coredata(dj), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(dj, prob=TRUE, 15) # histogram
lines(density(tsclean(dj))) # smooth it - ?density for details
qqnorm(tsclean(dj),main="Normal QQplot of timeseries") # normal Q-Q plot
qqline(dj)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(dj), 5000, replace = FALSE)
# W = 0.9105, p-value < 2.2e-16
# Plot with title “Normal QQplot of timeseries”

# %% [markdown]
# Null hypothesis for normality is rejected in all cases according to the Shapiro tests and qqplots. So we will need to consider the BoxCox transformation in the training process.

# %% [markdown]
# ### Box Cox transform
# A sample Box Cox transformation

# %%
normalised=BoxCox(dj, 0.55)
shapiro.test(sample(coredata(normalised), 5000, replace=FALSE))
par(mfrow=c(2,1))
hist(normalised, prob=TRUE, 15) # histogram
lines(density(tsclean(normalised))) # smooth it - ?density for details
qqnorm(tsclean(normalised), main="Normal QQplot of diff log timeseries") # normal Q-Q plot
qqline(normalised)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(normalised), 5000, replace = FALSE)
# W = 0.99557, p-value = 3.505e-11
# Plot with title “Normal QQplot of diff log timeseries”

# %% [markdown]
# The box cox transform is somehow effective

# %%
ltrain = j['/2021-06-25 23:30:00']
ltest = j['2021-06-25 00:00:00/']

# %% [markdown]
# ### tbats

# %% [markdown]
# Seasonal periods: 24 (daily), 168 (weekly). (1 day = 48 * 30 min timesteps)

# %%
tb <- tbats(tsclean(ltrain), use.box.cox = TRUE, use.trend = TRUE,
            seasonal.periods=c(24, 168), use.arma.errors=TRUE, 
            use.parallel=TRUE, num.cores=6, biasadj=TRUE)
tb
# Out:
# TBATS(1, {0,0}, 0.8, {<24,11>, <168,2>})
#
# Call: tbats(y = tsclean(ltrain), use.box.cox = TRUE, use.trend = TRUE,
#     seasonal.periods = c(24, 168), use.arma.errors = TRUE, use.parallel = TRUE,
#     num.cores = 6, biasadj = TRUE)
#
# Parameters
#   Lambda: 0.999997
#   Alpha: 0.6605808
#   Beta: -0.1472744
#   Damping Parameter: 0.800005
#   Gamma-1 Values: 4.136955e-06 0.0004750427
#   Gamma-2 Values: 1.756982e-05 0.0002729328
#
# Seed States:
#              [,1]
#  [1,] 4325.039392
#  [2,] -244.351472
#  [3,]   15.608989
#  [4,]  -92.982629
#  [5,]   -2.104746
#  [6,]  -60.558528
#  [7,]  -24.274673
#  [8,]   -4.452906
#  [9,]  -17.891468
# [10,]   17.182907
# [11,]    8.695867
# [12,]    2.723794
# [13,]   17.272312
# [14,]  228.501305
# [15,]    2.575411
# [16,]   45.895853
# [17,]   30.791727
# [18,]  -33.996841
# [19,]  -10.806727
# [20,]  -27.519679
# [21,]  -10.055464
# [22,]    3.653246
# [23,]  -16.899753
# [24,]    3.196062
# [25,]  -45.261873
# [26,]  -14.203953
# [27,]    1.396972
# [28,]   -4.242891
# attr(,"lambda")
# [1] 0.9999968
#
# Sigma: 295.7421
# AIC: 111201.2

# %%
acf(resid(tb),lag.max = 100)
pacf(resid(tb),lag.max=100)
# Out:
# Plot with title “Series  resid(tb)”
# Plot with title “Series  resid(tb)”

# %% [markdown]
# Tbats retains some systematic patterns in residuals. I does not produce the best of results as also demostrated in the python notebook.

# %% [markdown]
# ### ARIMA and SARIMA
# ACF and PACF is plotted again in order to have a look at the possible ar, ma and respective seasonal (sma, sar) terms.

# %%
acf(tsclean(dj))
pacf(tsclean(dj))
# Out:
# Plot with title “Series  tsclean(dj)”
# Plot with title “Series  tsclean(dj)”

# %% [markdown]
# Most probable models based on the ACF and PACF are ma(4), ar(2) or ar(4), sma(24, 48, ...), sar(24, 48, ...) along with a differentiation term.

# %% [markdown]
# auto.arima is trained on the time series

# %%
auto <- auto.arima(ltrain)
summary(auto)
# Out:
# Series: ltrain
# ARIMA(5,1,2)
#
# Coefficients:
#          ar1      ar2     ar3      ar4      ar5      ma1     ma2
#       1.4460  -0.4110  0.0173  -0.1020  -0.0553  -1.8748  0.8945
# s.e.  0.0169   0.0246  0.0242   0.0238   0.0152   0.0101  0.0121
#
# sigma^2 estimated as 94958:  log likelihood=-39713.17
# AIC=79442.34   AICc=79442.36   BIC=79495.32
#
# Training set error measures:
#                     ME    RMSE      MAE       MPE     MAPE      MASE
# Training set -1.452805 307.931 214.1125 -1.537902 8.553059 0.0756289
#                      ACF1
# Training set -0.006120889

# %% [markdown]
# An extended summary is also provided using the sarima function of astsa package.

# %%
sarima(j, 5, 1, 2, 0, 0, 0)
# Out:
# initial  value 5.844872
# iter   2 value 5.816562
# iter   3 value 5.792290
# iter   4 value 5.791500
# iter   5 value 5.791461
# iter   6 value 5.791434
# iter   7 value 5.791429
# iter   8 value 5.791359
# iter   9 value 5.790061
# iter  10 value 5.789551
# iter  11 value 5.788432
# iter  12 value 5.787646
# iter  13 value 5.784521
# iter  14 value 5.779698
# iter  15 value 5.773731
# iter  16 value 5.766872
# iter  17 value 5.759426
# iter  18 value 5.755350
# iter  19 value 5.753834
# iter  20 value 5.753344
# iter  21 value 5.753322
# iter  22 value 5.753306
# iter  23 value 5.753300
# iter  24 value 5.753298
# iter  25 value 5.753297
# iter  26 value 5.753297
# iter  27 value 5.753296
# iter  28 value 5.753294
# iter  29 value 5.753289
# iter  30 value 5.753275
# iter  31 value 5.753244
# iter  32 value 5.753192
# iter  33 value 5.753180
# iter  34 value 5.753160
# iter  35 value 5.753149
# iter  36 value 5.753131
# iter  37 value 5.753130
# iter  38 value 5.753130
# iter  38 value 5.753129
# iter  38 value 5.753129
# final  value 5.753129
# converged
# initial  value 5.752437
# iter   2 value 5.752365
# iter   3 value 5.752358
# iter   4 value 5.752356
# iter   5 value 5.752351
# iter   6 value 5.752351
# iter   7 value 5.752351
# iter   8 value 5.752350
# iter   9 value 5.752349
# iter  10 value 5.752345
# iter  11 value 5.752336
# iter  12 value 5.752314
# iter  13 value 5.752264
# iter  14 value 5.752231
# iter  15 value 5.752168
# iter  16 value 5.752115
# iter  17 value 5.752099
# iter  18 value 5.751613
# iter  19 value 5.751577
# iter  20 value 5.750980
# iter  21 value 5.750742
# iter  22 value 5.750729
# iter  23 value 5.750690
# iter  24 value 5.750610
# iter  25 value 5.750413
# iter  26 value 5.749672
# iter  27 value 5.749286
# iter  28 value 5.748758
# iter  29 value 5.748326
# iter  30 value 5.740640
# iter  31 value 5.739702
# iter  32 value 5.737859
# iter  33 value 5.732852
# iter  34 value 5.732033
# iter  35 value 5.731739
# iter  36 value 5.731716
# iter  37 value 5.731299
# iter  38 value 5.731107
# iter  39 value 5.731077
# iter  40 value 5.731075
# iter  41 value 5.731075
# iter  42 value 5.731073
# iter  43 value 5.731071
# iter  44 value 5.731069
# iter  45 value 5.731069
# iter  45 value 5.731069
# iter  45 value 5.731069
# final  value 5.731069
# converged
# $fit
#
# Call:
# arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D, Q), period = S),
#     xreg = constant, transform.pars = trans, fixed = fixed, optim.control = list(trace = trc,
#         REPORT = 1, reltol = tol))
#
# Coefficients:
#          ar1      ar2     ar3      ar4      ar5      ma1     ma2  constant
#       1.4397  -0.4037  0.0236  -0.1123  -0.0535  -1.8757  0.8957   -0.2109
# s.e.  0.0167   0.0243  0.0239   0.0235   0.0150   0.0100  0.0122    0.7721
#
# sigma^2 estimated as 95014:  log likelihood = -40576.29,  aic = 81170.58
#
# $degrees_of_freedom
# [1] 5667
#
# $ttable
#          Estimate     SE   t.value p.value
# ar1        1.4397 0.0167   86.0494  0.0000
# ar2       -0.4037 0.0243  -16.6276  0.0000
# ar3        0.0236 0.0239    0.9902  0.3221
# ar4       -0.1123 0.0235   -4.7778  0.0000
# ar5       -0.0535 0.0150   -3.5671  0.0004
# ma1       -1.8757 0.0100 -186.6392  0.0000
# ma2        0.8957 0.0122   73.5938  0.0000
# constant  -0.2109 0.7721   -0.2731  0.7848
#
# $AIC
# [1] 14.30319
#
# $AICc
# [1] 14.30319
#
# $BIC
# [1] 14.31372
# Plot with title “p values for Ljung-Box statistic”

# %% [markdown]
# The model seems to ignore seasonal terms. It also produces systematic residuals. Therfore we proceed to further inspection with gridsearch...

# %%
d=1
DD=1
per=24

aics <- c()
c <- 0

for(p in 5:1){
  for(q in 2:1){
    for(i in 5:1){
      for(k in 5:1){
        if(p+d+q+i+DD+k<=20){
          c <- c + 1
          tryCatch({
              
              model <- arima(x=j, order=c((p-1),d,(q-1)), 
                             seasonal=list(order=c((i-1),DD,(k-1)), 
                             period=per))
              pval<-Box.test(model$residuals, lag=log(length(model$residuals)))
              sse<-sum(model$residuals^2)
              cat(c, ". ", p-1,d,q-1,i-1,DD,k-1,per, 'AIC=', model$aic, ', SSE=',sse,', Residual correlation p-VALUE=', pval$p.value,'\n')
              aics <- c(aics, model$aic)
              
              }, error = function(e) {cat(c, ". ", p-1,d,q-1,i-1,DD,k-1,per, 'Failed!\n')
                                      aics <- c(aics, 1000000000)})

        }
      }
    }
  }
}
cat('Minimum AIC: ', min(aics), "\nModel id: ", which.min(aics))
# Out:
# 1 .  4 1 1 4 1 4 24 Failed!
# 2 .  4 1 1 4 1 3 24 Failed!
# 3 .  4 1 1 4 1 2 24 Failed!
# 4 .  4 1 1 4 1 1 24 Failed!
# 5 .  4 1 1 4 1 0 24 Failed!
# 6 .  4 1 1 3 1 4 24 Failed!
# 7 .  4 1 1 3 1 3 24 Failed!
# 8 .  4 1 1 3 1 2 24 Failed!
# 9 .  4 1 1 3 1 1 24 Failed!
# 10 .  4 1 1 3 1 0 24 Failed!
# 11 .  4 1 1 2 1 4 24 AIC= 79776.02  SSE= 442053795 Residual correlation p-VALUE= 0.08616061
# Warning message in log(s2):
# “NaNs produced”
# Warning message in log(s2):
# “NaNs produced”
# 12 .  4 1 1 2 1 3 24 AIC= 79780.17  SSE= 442537074 Residual correlation p-VALUE= 0.04313842
# 13 .  4 1 1 2 1 2 24 AIC= 79791.39  SSE= 443616494 Residual correlation p-VALUE= 0.09146054
# 14 .  4 1 1 2 1 1 24 AIC= 79771.91  SSE= 442175939 Residual correlation p-VALUE= 0.07303223
# 15 .  4 1 1 2 1 0 24 AIC= 80775.85  SSE= 531240186 Residual correlation p-VALUE= 0.0106738
# 16 .  4 1 1 1 1 4 24 AIC= 79775.09  SSE= 442106412 Residual correlation p-VALUE= 0.07545546
# 17 .  4 1 1 1 1 3 24 AIC= 79773.34  SSE= 442122508 Residual correlation p-VALUE= 0.07232922
# 18 .  4 1 1 1 1 2 24 AIC= 79776.18  SSE= 442489728 Residual correlation p-VALUE= 0.07423786
# 19 .  4 1 1 1 1 1 24 AIC= 79787.84  SSE= 443636652 Residual correlation p-VALUE= 0.09110757
# 20 .  4 1 1 1 1 0 24 AIC= 81238.05  SSE= 576557961 Residual correlation p-VALUE= 7.335907e-08
# 21 .  4 1 1 0 1 4 24 AIC= 79773.12  SSE= 442106064 Residual correlation p-VALUE= 0.07367458
# 22 .  4 1 1 0 1 3 24 AIC= 79772.85  SSE= 442256329 Residual correlation p-VALUE= 0.07538971
# 23 .  4 1 1 0 1 2 24 AIC= 79789.74  SSE= 443798304 Residual correlation p-VALUE= 0.09064797
# 24 .  4 1 1 0 1 1 24 AIC= 79801.81  SSE= 444972987 Residual correlation p-VALUE= 0.0808348
# 25 .  4 1 1 0 1 0 24 AIC= 82735.46  SSE= 752687733 Residual correlation p-VALUE= 0.0001590257
# 26 .  4 1 0 4 1 4 24 AIC= 80190.02  SSE= 475712303 Residual correlation p-VALUE= 0
# 27 .  4 1 0 4 1 3 24 AIC= 80181.79  SSE= 475103176 Residual correlation p-VALUE= 0
# 28 .  4 1 0 4 1 2 24 AIC= 80178.73  SSE= 475020215 Residual correlation p-VALUE= 0
# 29 .  4 1 0 4 1 1 24 AIC= 80180.02  SSE= 475305875 Residual correlation p-VALUE= 0
# 30 .  4 1 0 4 1 0 24 AIC= 80734.17  SSE= 526656683 Residual correlation p-VALUE= 0
# 31 .  4 1 0 3 1 4 24 AIC= 80180.06  SSE= 474962944 Residual correlation p-VALUE= 0
# 32 .  4 1 0 3 1 3 24 AIC= 80176.86  SSE= 474851447 Residual correlation p-VALUE= 0
# 33 .  4 1 0 3 1 2 24 AIC= 80174.89  SSE= 474855936 Residual correlation p-VALUE= 0
# 34 .  4 1 0 3 1 1 24 AIC= 80178.06  SSE= 475298465 Residual correlation p-VALUE= 0
# 35 .  4 1 0 3 1 0 24 AIC= 80908.42  SSE= 543632974 Residual correlation p-VALUE= 0
# 36 .  4 1 0 2 1 4 24 AIC= 80175.25  SSE= 474620743 Residual correlation p-VALUE= 0
# 37 .  4 1 0 2 1 3 24 AIC= 80180.73  SSE= 475349783 Residual correlation p-VALUE= 0
# 38 .  4 1 0 2 1 2 24 AIC= 80178.16  SSE= 475305547 Residual correlation p-VALUE= 0
# 39 .  4 1 0 2 1 1 24 AIC= 80177.07  SSE= 475397480 Residual correlation p-VALUE= 0
# 40 .  4 1 0 2 1 0 24 AIC= 81164.78  SSE= 569401354 Residual correlation p-VALUE= 0
# 41 .  4 1 0 1 1 4 24 AIC= 80180.25  SSE= 475327211 Residual correlation p-VALUE= 0
# 42 .  4 1 0 1 1 3 24 AIC= 80178.17  SSE= 475315075 Residual correlation p-VALUE= 0
# 43 .  4 1 0 1 1 2 24 AIC= 80180.09  SSE= 475609707 Residual correlation p-VALUE= 0
# 44 .  4 1 0 1 1 1 24 AIC= 80193.17  SSE= 476995840 Residual correlation p-VALUE= 0
# 45 .  4 1 0 1 1 0 24 AIC= 81672.64  SSE= 623643439 Residual correlation p-VALUE= 0
# 46 .  4 1 0 0 1 4 24 AIC= 80178.02  SSE= 475302541 Residual correlation p-VALUE= 0
# 47 .  4 1 0 0 1 3 24 AIC= 80178.29  SSE= 475514784 Residual correlation p-VALUE= 0
# 48 .  4 1 0 0 1 2 24 AIC= 80194.51  SSE= 477119441 Residual correlation p-VALUE= 0
# 49 .  4 1 0 0 1 1 24 AIC= 80202.61  SSE= 478034081 Residual correlation p-VALUE= 0
# 50 .  4 1 0 0 1 0 24 AIC= 83272.77  SSE= 829061365 Residual correlation p-VALUE= 0
# 51 .  3 1 1 4 1 4 24 Failed!
# 52 .  3 1 1 4 1 3 24 Failed!
# 53 .  3 1 1 4 1 2 24 Failed!
# 54 .  3 1 1 4 1 1 24 Failed!
# 55 .  3 1 1 4 1 0 24 Failed!
# 56 .  3 1 1 3 1 4 24 Failed!
# 57 .  3 1 1 3 1 3 24 Failed!
# 58 .  3 1 1 3 1 2 24 Failed!
# 59 .  3 1 1 3 1 1 24 Failed!
# 60 .  3 1 1 3 1 0 24 Failed!
# 61 .  3 1 1 2 1 4 24 Failed!
# 62 .  3 1 1 2 1 3 24 AIC= 79813.88  SSE= 445411073 Residual correlation p-VALUE= 0.00042915
# 63 .  3 1 1 2 1 2 24 Failed!
# 64 .  3 1 1 2 1 1 24 AIC= 79784.94  SSE= 443340635 Residual correlation p-VALUE= 0.0004290507
# 65 .  3 1 1 2 1 0 24 AIC= 80784.37  SSE= 532207471 Residual correlation p-VALUE= 3.499747e-05
# 66 .  3 1 1 1 1 4 24 AIC= 79787.95  SSE= 443260799 Residual correlation p-VALUE= 0.000471581
# 67 .  3 1 1 1 1 3 24 AIC= 79786.23  SSE= 443279046 Residual correlation p-VALUE= 0.0004420442
# 68 .  3 1 1 1 1 2 24 AIC= 79788.77  SSE= 443624925 Residual correlation p-VALUE= 0.0005385449
# 69 .  3 1 1 1 1 1 24 AIC= 79800.87  SSE= 444812096 Residual correlation p-VALUE= 0.0006716174
# 70 .  3 1 1 1 1 0 24 AIC= 81239.54  SSE= 576919464 Residual correlation p-VALUE= 5.882672e-09
# 71 .  3 1 1 0 1 4 24 AIC= 79785.95  SSE= 443257689 Residual correlation p-VALUE= 0.0004641977
# 72 .  3 1 1 0 1 3 24 AIC= 79786.07  SSE= 443441449 Residual correlation p-VALUE= 0.0004255494
# 73 .  3 1 1 0 1 2 24 AIC= 79802.87  SSE= 444982292 Residual correlation p-VALUE= 0.0006658205
# 74 .  3 1 1 0 1 1 24 AIC= 79815.7  SSE= 446222874 Residual correlation p-VALUE= 0.0005083025
# 75 .  3 1 1 0 1 0 24 AIC= 82739.56  SSE= 753510123 Residual correlation p-VALUE= 4.931159e-06
# 76 .  3 1 0 4 1 4 24 Failed!
# 77 .  3 1 0 4 1 3 24 Failed!
# 78 .  3 1 0 4 1 2 24 Failed!
# 79 .  3 1 0 4 1 1 24 Failed!
# 80 .  3 1 0 4 1 0 24 Failed!
# 81 .  3 1 0 3 1 4 24 Failed!
# 82 .  3 1 0 3 1 3 24 Failed!
# 83 .  3 1 0 3 1 2 24 Failed!
# 84 .  3 1 0 3 1 1 24 Failed!
# 85 .  3 1 0 3 1 0 24 Failed!
# 86 .  3 1 0 2 1 4 24 AIC= 80275.08  SSE= 483321807 Residual correlation p-VALUE= 0
# 87 .  3 1 0 2 1 3 24 AIC= 80275  SSE= 483435178 Residual correlation p-VALUE= 0
# 88 .  3 1 0 2 1 2 24 AIC= 80288.38  SSE= 484858039 Residual correlation p-VALUE= 0
# 89 .  3 1 0 2 1 1 24 AIC= 80270.83  SSE= 483444808 Residual correlation p-VALUE= 0
# 90 .  3 1 0 2 1 0 24 AIC= 81278.56  SSE= 581191953 Residual correlation p-VALUE= 0
# 91 .  3 1 0 1 1 4 24 AIC= 80273.45  SSE= 483323306 Residual correlation p-VALUE= 0
# 92 .  3 1 0 1 1 3 24 AIC= 80271.96  SSE= 483366590 Residual correlation p-VALUE= 0
# 93 .  3 1 0 1 1 2 24 AIC= 80273.17  SSE= 483607127 Residual correlation p-VALUE= 0
# 94 .  3 1 0 1 1 1 24 AIC= 80284.51  SSE= 484857178 Residual correlation p-VALUE= 0
# 95 .  3 1 0 1 1 0 24 AIC= 81798.67  SSE= 637950839 Residual correlation p-VALUE= 0
# 96 .  3 1 0 0 1 4 24 AIC= 80271.49  SSE= 483321795 Residual correlation p-VALUE= 0
# 97 .  3 1 0 0 1 3 24 AIC= 80271.85  SSE= 483546262 Residual correlation p-VALUE= 0
# 98 .  3 1 0 0 1 2 24 AIC= 80285.8  SSE= 484978539 Residual correlation p-VALUE= 0
# 99 .  3 1 0 0 1 1 24 AIC= 80294.38  SSE= 485949138 Residual correlation p-VALUE= 0
# 100 .  3 1 0 0 1 0 24 AIC= 83385.47  SSE= 846072182 Residual correlation p-VALUE= 0
# 101 .  2 1 1 4 1 4 24 Failed!
# 102 .  2 1 1 4 1 3 24 Failed!
# 103 .  2 1 1 4 1 2 24 Failed!
# 104 .  2 1 1 4 1 1 24 Failed!
# 105 .  2 1 1 4 1 0 24 Failed!
# 106 .  2 1 1 3 1 4 24 Failed!
# 107 .  2 1 1 3 1 3 24 Failed!
# 108 .  2 1 1 3 1 2 24 Failed!
# 109 .  2 1 1 3 1 1 24 Failed!
# 110 .  2 1 1 3 1 0 24 Failed!
# 111 .  2 1 1 2 1 4 24 Failed!
# 112 .  2 1 1 2 1 3 24 Failed!
# 113 .  2 1 1 2 1 2 24 Failed!
# 114 .  2 1 1 2 1 1 24 Failed!
# 115 .  2 1 1 2 1 0 24 Failed!
# 116 .  2 1 1 1 1 4 24 AIC= 79830.18  SSE= 446784843 Residual correlation p-VALUE= 1.338929e-13
# 117 .  2 1 1 1 1 3 24 AIC= 79831.43  SSE= 447044519 Residual correlation p-VALUE= 1.304512e-13
# 118 .  2 1 1 1 1 2 24 AIC= 79834.73  SSE= 447450822 Residual correlation p-VALUE= 1.083578e-13
# 119 .  2 1 1 1 1 1 24 AIC= 79846.33  SSE= 448605203 Residual correlation p-VALUE= 1.29563e-13
# 120 .  2 1 1 1 1 0 24 AIC= 81324.27  SSE= 586452232 Residual correlation p-VALUE= 2.009504e-14
# 121 .  2 1 1 0 1 4 24 AIC= 79831.18  SSE= 447024565 Residual correlation p-VALUE= 1.34448e-13
# 122 .  2 1 1 0 1 3 24 AIC= 79830.95  SSE= 447178742 Residual correlation p-VALUE= 1.314504e-13
# 123 .  2 1 1 0 1 2 24 AIC= 79847.95  SSE= 448744034 Residual correlation p-VALUE= 1.433298e-13
# 124 .  2 1 1 0 1 1 24 AIC= 79857.94  SSE= 449757669 Residual correlation p-VALUE= 2.832179e-13
# 125 .  2 1 1 0 1 0 24 AIC= 82819.31  SSE= 764461522 Residual correlation p-VALUE= 0
# 126 .  2 1 0 4 1 4 24 Failed!
# 127 .  2 1 0 4 1 3 24 Failed!
# 128 .  2 1 0 4 1 2 24 Failed!
# 129 .  2 1 0 4 1 1 24 AIC= 80300.12  SSE= 485764903 Residual correlation p-VALUE= 0
# 130 .  2 1 0 4 1 0 24 Failed!
# 131 .  2 1 0 3 1 4 24 AIC= 80300.67  SSE= 485460866 Residual correlation p-VALUE= 0
# 132 .  2 1 0 3 1 3 24 AIC= 80298.37  SSE= 485430580 Residual correlation p-VALUE= 0
# 133 .  2 1 0 3 1 2 24 AIC= 80295.8  SSE= 485363383 Residual correlation p-VALUE= 0
# 134 .  2 1 0 3 1 1 24 AIC= 80297.8  SSE= 485706204 Residual correlation p-VALUE= 0
# 135 .  2 1 0 3 1 0 24 AIC= 81058.95  SSE= 558710387 Residual correlation p-VALUE= 0
# Warning message in log(s2):
# “NaNs produced”
# 136 .  2 1 0 2 1 4 24 AIC= 80294.83  SSE= 485091188 Residual correlation p-VALUE= 0
# 137 .  2 1 0 2 1 3 24 AIC= 80301.31  SSE= 485832342 Residual correlation p-VALUE= 0
# 138 .  2 1 0 2 1 2 24 AIC= 80297.97  SSE= 485705942 Residual correlation p-VALUE= 0
# 139 .  2 1 0 2 1 1 24 AIC= 80296.67  SSE= 485795898 Residual correlation p-VALUE= 0
# 140 .  2 1 0 2 1 0 24 AIC= 81315.16  SSE= 585178006 Residual correlation p-VALUE= 0
# 141 .  2 1 0 1 1 4 24 AIC= 80299.5  SSE= 485692098 Residual correlation p-VALUE= 0
# 142 .  2 1 0 1 1 3 24 AIC= 80298  SSE= 485736302 Residual correlation p-VALUE= 0
# 143 .  2 1 0 1 1 2 24 AIC= 80299.37  SSE= 485991417 Residual correlation p-VALUE= 0
# 144 .  2 1 0 1 1 1 24 AIC= 80310.6  SSE= 487239323 Residual correlation p-VALUE= 0
# 145 .  2 1 0 1 1 0 24 AIC= 81831.93  SSE= 641942907 Residual correlation p-VALUE= 0
# 146 .  2 1 0 0 1 4 24 AIC= 80297.58  SSE= 485694554 Residual correlation p-VALUE= 0
# 147 .  2 1 0 0 1 3 24 AIC= 80297.58  SSE= 485888443 Residual correlation p-VALUE= 0
# 148 .  2 1 0 0 1 2 24 AIC= 80311.87  SSE= 487358637 Residual correlation p-VALUE= 0
# 149 .  2 1 0 0 1 1 24 AIC= 80320.16  SSE= 488310276 Residual correlation p-VALUE= 0
# 150 .  2 1 0 0 1 0 24 AIC= 83426.41  SSE= 852529313 Residual correlation p-VALUE= 0
# 151 .  1 1 1 4 1 4 24 Failed!
# 152 .  1 1 1 4 1 3 24 Failed!
# 153 .  1 1 1 4 1 2 24 Failed!
# 154 .  1 1 1 4 1 1 24 Failed!
# 155 .  1 1 1 4 1 0 24 Failed!
# 156 .  1 1 1 3 1 4 24 Failed!
# 157 .  1 1 1 3 1 3 24 Failed!
# 158 .  1 1 1 3 1 2 24 Failed!
# 159 .  1 1 1 3 1 1 24 Failed!
# 160 .  1 1 1 3 1 0 24 Failed!
# 161 .  1 1 1 2 1 4 24 AIC= 79922.4  SSE= 454251560 Residual correlation p-VALUE= 0
# 162 .  1 1 1 2 1 3 24 AIC= 79927.1  SSE= 454806906 Residual correlation p-VALUE= 0
# 163 .  1 1 1 2 1 2 24 AIC= 79918.06  SSE= 454208195 Residual correlation p-VALUE= 0
# 164 .  1 1 1 2 1 1 24 AIC= 79916.81  SSE= 454274382 Residual correlation p-VALUE= 0
# 165 .  1 1 1 2 1 0 24 AIC= 80891.78  SSE= 542872588 Residual correlation p-VALUE= 0
# 166 .  1 1 1 1 1 4 24 AIC= 79919.63  SSE= 454175603 Residual correlation p-VALUE= 0
# 167 .  1 1 1 1 1 3 24 AIC= 79917.88  SSE= 454193096 Residual correlation p-VALUE= 0
# 168 .  1 1 1 1 1 2 24 AIC= 79920.43  SSE= 454551804 Residual correlation p-VALUE= 0
# 169 .  1 1 1 1 1 1 24 AIC= 79931.57  SSE= 455667220 Residual correlation p-VALUE= 0
# 170 .  1 1 1 1 1 0 24 AIC= 81391.52  SSE= 593740123 Residual correlation p-VALUE= 0
# 171 .  1 1 1 0 1 4 24 AIC= 79917.63  SSE= 454175927 Residual correlation p-VALUE= 0
# 172 .  1 1 1 0 1 3 24 AIC= 79917.96  SSE= 454376013 Residual correlation p-VALUE= 0
# 173 .  1 1 1 0 1 2 24 AIC= 79933.1  SSE= 455799420 Residual correlation p-VALUE= 0
# 174 .  1 1 1 0 1 1 24 AIC= 79943.12  SSE= 456822597 Residual correlation p-VALUE= 0
# 175 .  1 1 1 0 1 0 24 AIC= 82967.92  SSE= 785996643 Residual correlation p-VALUE= 2.88658e-15
# 176 .  1 1 0 4 1 4 24 Failed!
# 177 .  1 1 0 4 1 3 24 Failed!
# 178 .  1 1 0 4 1 2 24 Failed!
# 179 .  1 1 0 4 1 1 24 Failed!
# 180 .  1 1 0 4 1 0 24 Failed!
# 181 .  1 1 0 3 1 4 24 Failed!
# 182 .  1 1 0 3 1 3 24 Failed!
# 183 .  1 1 0 3 1 2 24 Failed!
# 184 .  1 1 0 3 1 1 24 Failed!
# 185 .  1 1 0 3 1 0 24 AIC= 81393.38  SSE= 593270863 Residual correlation p-VALUE= 0
# 186 .  1 1 0 2 1 4 24 AIC= 80619.92  SSE= 513929758 Residual correlation p-VALUE= 0
# 187 .  1 1 0 2 1 3 24 AIC= 80624.3  SSE= 514494423 Residual correlation p-VALUE= 0
# 188 .  1 1 0 2 1 2 24 AIC= 80622.1  SSE= 514487542 Residual correlation p-VALUE= 0
# 189 .  1 1 0 2 1 1 24 AIC= 80620.6  SSE= 514544475 Residual correlation p-VALUE= 0
# 190 .  1 1 0 2 1 0 24 AIC= 81658.97  SSE= 622085420 Residual correlation p-VALUE= 0
# 191 .  1 1 0 1 1 4 24 AIC= 80623.76  SSE= 514466489 Residual correlation p-VALUE= 0
# 192 .  1 1 0 1 1 3 24 AIC= 80621.96  SSE= 514478075 Residual correlation p-VALUE= 0
# 193 .  1 1 0 1 1 2 24 AIC= 80624.83  SSE= 514862971 Residual correlation p-VALUE= 0
# 194 .  1 1 0 1 1 1 24 AIC= 80636.39  SSE= 516260795 Residual correlation p-VALUE= 0
# 195 .  1 1 0 1 1 0 24 AIC= 82178.13  SSE= 682722665 Residual correlation p-VALUE= 0
# 196 .  1 1 0 0 1 4 24 AIC= 80621.84  SSE= 514470233 Residual correlation p-VALUE= 0
# 197 .  1 1 0 0 1 3 24 AIC= 80621.16  SSE= 514610784 Residual correlation p-VALUE= 0
# 198 .  1 1 0 0 1 2 24 AIC= 80637.07  SSE= 516330386 Residual correlation p-VALUE= 0
# 199 .  1 1 0 0 1 1 24 AIC= 80640.31  SSE= 516860111 Residual correlation p-VALUE= 0
# 200 .  1 1 0 0 1 0 24 AIC= 83842.2  SSE= 917971505 Residual correlation p-VALUE= 0
# 201 .  0 1 1 4 1 4 24 AIC= 80166.43  SSE= 474256528 Residual correlation p-VALUE= 0
# 202 .  0 1 1 4 1 3 24 AIC= 80164.54  SSE= 474272724 Residual correlation p-VALUE= 0
# 203 .  0 1 1 4 1 2 24 AIC= 80162.58  SSE= 474274640 Residual correlation p-VALUE= 0
# 204 .  0 1 1 4 1 1 24 AIC= 80164.34  SSE= 474601129 Residual correlation p-VALUE= 0
# 205 .  0 1 1 4 1 0 24 AIC= 80709.07  SSE= 524917045 Residual correlation p-VALUE= 0
# 206 .  0 1 1 3 1 4 24 AIC= 80156.32  SSE= 473497718 Residual correlation p-VALUE= 0
# 207 .  0 1 1 3 1 3 24 AIC= 80162.76  SSE= 474290724 Residual correlation p-VALUE= 0
# 208 .  0 1 1 3 1 2 24 AIC= 80160.54  SSE= 474267534 Residual correlation p-VALUE= 0
# 209 .  0 1 1 3 1 1 24 AIC= 80162.71  SSE= 474624807 Residual correlation p-VALUE= 0
# 210 .  0 1 1 3 1 0 24 AIC= 80880.56  SSE= 541570577 Residual correlation p-VALUE= 0
# 211 .  0 1 1 2 1 4 24 AIC= 80162.96  SSE= 474305974 Residual correlation p-VALUE= 0
# 212 .  0 1 1 2 1 3 24 AIC= 80166.45  SSE= 474769307 Residual correlation p-VALUE= 0
# 213 .  0 1 1 2 1 2 24 AIC= 80162.91  SSE= 474643634 Residual correlation p-VALUE= 0
# 214 .  0 1 1 2 1 1 24 AIC= 80161.59  SSE= 474709684 Residual correlation p-VALUE= 0
# 215 .  0 1 1 2 1 0 24 AIC= 81119.12  SSE= 565435943 Residual correlation p-VALUE= 0
# 216 .  0 1 1 1 1 4 24 AIC= 80164.28  SSE= 474598154 Residual correlation p-VALUE= 0
# 217 .  0 1 1 1 1 3 24 AIC= 80162.62  SSE= 474620807 Residual correlation p-VALUE= 0
# 218 .  0 1 1 1 1 2 24 AIC= 80166.36  SSE= 475087194 Residual correlation p-VALUE= 0
# 219 .  0 1 1 1 1 1 24 AIC= 80180.11  SSE= 476504899 Residual correlation p-VALUE= 0
# 220 .  0 1 1 1 1 0 24 AIC= 81604.26  SSE= 616793960 Residual correlation p-VALUE= 0
# 221 .  0 1 1 0 1 4 24 AIC= 80162.23  SSE= 474590559 Residual correlation p-VALUE= 0
# 222 .  0 1 1 0 1 3 24 AIC= 80162.84  SSE= 474828982 Residual correlation p-VALUE= 0
# 223 .  0 1 1 0 1 2 24 AIC= 80181.89  SSE= 476665460 Residual correlation p-VALUE= 0
# 224 .  0 1 1 0 1 1 24 AIC= 80192.26  SSE= 477769245 Residual correlation p-VALUE= 0
# 225 .  0 1 1 0 1 0 24 AIC= 83173.94  SSE= 815522367 Residual correlation p-VALUE= 0
# 226 .  0 1 0 4 1 4 24 AIC= 81413.15  SSE= 590720097 Residual correlation p-VALUE= 0
# 227 .  0 1 0 4 1 3 24 AIC= 81413.14  SSE= 590895323 Residual correlation p-VALUE= 0
# 228 .  0 1 0 4 1 2 24 AIC= 81406.39  SSE= 590385698 Residual correlation p-VALUE= 0
# 229 .  0 1 0 4 1 1 24 AIC= 81411.37  SSE= 591113682 Residual correlation p-VALUE= 0
# 230 .  0 1 0 4 1 0 24 AIC= 82028.06  SSE= 662966422 Residual correlation p-VALUE= 0
# 231 .  0 1 0 3 1 4 24 AIC= 81408.86  SSE= 590397453 Residual correlation p-VALUE= 0
# 232 .  0 1 0 3 1 3 24 AIC= 81406.23  SSE= 590368869 Residual correlation p-VALUE= 0
# 233 .  0 1 0 3 1 2 24 AIC= 81404.26  SSE= 590375067 Residual correlation p-VALUE= 0
# 234 .  0 1 0 3 1 1 24 AIC= 81409.48  SSE= 591135218 Residual correlation p-VALUE= 0
# 235 .  0 1 0 3 1 0 24 AIC= 82223.06  SSE= 686898368 Residual correlation p-VALUE= 0
# 236 .  0 1 0 2 1 4 24 AIC= 81407.52  SSE= 590539893 Residual correlation p-VALUE= 0
# 237 .  0 1 0 2 1 3 24 AIC= 81421.13  SSE= 592295880 Residual correlation p-VALUE= 0
# 238 .  0 1 0 2 1 2 24 AIC= 81409.54  SSE= 591143692 Residual correlation p-VALUE= 0
# 239 .  0 1 0 2 1 1 24 AIC= 81409.17  SSE= 591349155 Residual correlation p-VALUE= 0
# 240 .  0 1 0 2 1 0 24 AIC= 82513.08  SSE= 723812270 Residual correlation p-VALUE= 0
# 241 .  0 1 0 1 1 4 24 AIC= 81411.71  SSE= 591169996 Residual correlation p-VALUE= 0
# 242 .  0 1 0 1 1 3 24 AIC= 81409.56  SSE= 591150579 Residual correlation p-VALUE= 0
# 243 .  0 1 0 1 1 2 24 AIC= 81407.56  SSE= 591050135 Residual correlation p-VALUE= 0
# 244 .  0 1 0 1 1 1 24 AIC= 81417.1  SSE= 592486841 Residual correlation p-VALUE= 0
# 245 .  0 1 0 1 1 0 24 AIC= 83090.02  SSE= 802600301 Residual correlation p-VALUE= 0
# 246 .  0 1 0 0 1 4 24 AIC= 81409.79  SSE= 591183232 Residual correlation p-VALUE= 0
# 247 .  0 1 0 0 1 3 24 AIC= 81409.87  SSE= 591440411 Residual correlation p-VALUE= 0
# 248 .  0 1 0 0 1 2 24 AIC= 81417.47  SSE= 592533252 Residual correlation p-VALUE= 0
# 249 .  0 1 0 0 1 1 24 AIC= 81419.49  SSE= 593013003 Residual correlation p-VALUE= 0
# 250 .  0 1 0 0 1 0 24 AIC= 84729.49  SSE= 1074448588 Residual correlation p-VALUE= 0
# Minimum AIC:  79771.91
# Model id:  4

# %% [markdown]
# #### Extensive residual summary of the best model:

# %%
sarima(j, 4, 1, 1, 2, 1, 3, 24)
# Out:
# initial  value 6.082069
# iter   2 value 5.825058
# iter   3 value 5.777033
# iter   4 value 5.725484
# iter   5 value 5.701010
# iter   6 value 5.679264
# iter   7 value 5.674947
# iter   8 value 5.671439
# iter   9 value 5.670630
# iter  10 value 5.670205
# iter  11 value 5.668977
# iter  12 value 5.666043
# iter  13 value 5.663569
# iter  14 value 5.662008
# iter  15 value 5.661404
# iter  16 value 5.659918
# iter  17 value 5.656359
# iter  18 value 5.651307
# iter  19 value 5.650781
# iter  20 value 5.649483
# iter  21 value 5.645729
# iter  22 value 5.644566
# iter  23 value 5.644475
# iter  24 value 5.644449
# iter  25 value 5.644414
# iter  26 value 5.644332
# iter  27 value 5.644151
# iter  28 value 5.643847
# iter  29 value 5.643467
# iter  30 value 5.643188
# iter  31 value 5.643134
# iter  32 value 5.643110
# iter  33 value 5.643098
# iter  34 value 5.643095
# iter  35 value 5.643094
# iter  36 value 5.643094
# iter  37 value 5.643093
# iter  38 value 5.643090
# iter  39 value 5.643067
# iter  40 value 5.643027
# iter  41 value 5.642991
# iter  42 value 5.642947
# iter  43 value 5.642944
# iter  44 value 5.642944
# iter  45 value 5.642944
# iter  46 value 5.642943
# iter  47 value 5.642942
# iter  48 value 5.642939
# iter  49 value 5.642933
# iter  50 value 5.642927
# iter  51 value 5.642924
# iter  52 value 5.642924
# iter  52 value 5.642923
# iter  52 value 5.642923
# final  value 5.642923
# converged
# initial  value 5.639821
# iter   2 value 5.639760
# iter   3 value 5.639657
# iter   4 value 5.639602
# iter   5 value 5.639594
# iter   6 value 5.639577
# iter   7 value 5.639574
# iter   8 value 5.639572
# iter   9 value 5.639561
# iter  10 value 5.639542
# iter  11 value 5.639490
# iter  12 value 5.639433
# iter  13 value 5.639374
# iter  14 value 5.639359
# iter  15 value 5.639354
# Warning message in log(s2):
# “NaNs produced”
# iter  16 value 5.639349
# iter  17 value 5.639341
# iter  18 value 5.639325
# iter  19 value 5.639208
# iter  20 value 5.638715
# iter  21 value 5.638389
# iter  22 value 5.638352
# iter  23 value 5.638327
# iter  24 value 5.638300
# iter  25 value 5.638288
# iter  26 value 5.638251
# iter  27 value 5.638220
# iter  28 value 5.638094
# Warning message in log(s2):
# “NaNs produced”
# iter  29 value 5.638075
# iter  30 value 5.638063
# iter  31 value 5.638058
# iter  31 value 5.638087
# final  value 5.638058
# converged
# Warning message in sqrt(diag(fitit$var.coef)):
# “NaNs produced”
# Warning message in sqrt(diag(fitit$var.coef)):
# “NaNs produced”
# Warning message in sqrt(diag(x$var.coef)):
# “NaNs produced”
# $fit
#
# Call:
# arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D, Q), period = S),
#     include.mean = !no.constant, transform.pars = trans, fixed = fixed, optim.control = list(trace = trc,
#         REPORT = 1, reltol = tol))
#
# Coefficients:
#         ar1     ar2     ar3      ar4      ma1    sar1     sar2     sma1    sma2
#       0.412  0.1183  0.1096  -0.0492  -0.9634  0.0588  -0.1952  -0.9216  0.2515
# s.e.    NaN  0.0028  0.0050      NaN   0.0046     NaN      NaN   0.0077     NaN
#          sma3
#       -0.2309
# s.e.      NaN
#
# sigma^2 estimated as 78311:  log likelihood = -39879.09,  aic = 79780.17
#
# $degrees_of_freedom
# [1] 5641
#
# $ttable
#      Estimate     SE   t.value p.value
# ar1    0.4120    NaN       NaN     NaN
# ar2    0.1183 0.0028   42.2663       0
# ar3    0.1096 0.0050   22.1129       0
# ar4   -0.0492    NaN       NaN     NaN
# ma1   -0.9634 0.0046 -209.9870       0
# sar1   0.0588    NaN       NaN     NaN
# sar2  -0.1952    NaN       NaN     NaN
# sma1  -0.9216 0.0077 -119.2355       0
# sma2   0.2515    NaN       NaN     NaN
# sma3  -0.2309    NaN       NaN     NaN
#
# $AIC
# [1] 14.06066
#
# $AICc
# [1] 14.06066
#
# $BIC
# [1] 14.07353
# Plot with title “p values for Ljung-Box statistic”

# %% [markdown]
# Residuals still demonstrate systematic patterns while their variance seems to have some volatility especially at the sides of the diagram. Furthermore p-values are marginal that is a bit higher than 0.05. In any case this is the best arima model and will be used for forecasting as well. The auto.arima selected model is ignored (despite of the lower AIC value) as it is clear from the residual ACF that correlations are much bigger than the almost insignificant ones of this particular seasonal model.

# %% [markdown]
# # Final observations
# 1. We need to take into account that despite the yearly seasonality we do not posess data of a whole year and therefore we cannot model this pattern. This seems to somehow confuse the models.
# 2. Best sarima model is used in python to produce forecasts and evaluate them.
