# %%
library(forecast)
library(urca)
library(tseries)
library(zoo)
library(xts)
library(repr)
library(dplyr)

# %% [markdown]
# # Load data

# %%
data <- read.table("../VEOLIA/artifacts/timeseries_60min.csv", sep=',', header=TRUE)
y <- data['Diff.Load.Activa.Total..60.minuto.']

# %% [markdown]
# # Create time series

# %%
start.time <- as.POSIXlt("2020-11-01 00:00:00")
tsdat <- xts(y, seq(start.time, start.time + 20907000, by=3600))

print("Univariate time series created:")
head(as.matrix(tsdat))
# Out:
# [1] "Univariate time series created:"
#                     Diff.Load.Activa.Total..60.minuto.
# 2020-11-01 00:00:00 NA
# 2020-11-01 01:00:00 NA
# 2020-11-01 01:00:00 NA
# 2020-11-01 02:00:00 NA
# 2020-11-01 03:00:00 NA
# 2020-11-01 04:00:00 NA

# %% [markdown]
# # Clean initial zeros
# Initial 5 days zero values are cleaned as they are due to lack of mesurements.

# %%
j <- tsdat['2020-11-05 11:00:00/']
head(as.matrix(j))
j[is.na(j)]
# Out:
#                     Diff.Load.Activa.Total..60.minuto.
# 2020-11-05 11:00:00 NA
# 2020-11-05 12:00:00 NA
# 2020-11-05 13:00:00 NA
# 2020-11-05 14:00:00 NA
# 2020-11-05 15:00:00 NA
# 2020-11-05 16:00:00 NA
#                     Diff.Load.Activa.Total..60.minuto.
# 2020-11-05 11:00:00                                 NA
# 2020-11-05 12:00:00                                 NA
# 2020-11-05 13:00:00                                 NA
# 2020-11-05 14:00:00                                 NA
# 2020-11-05 15:00:00                                 NA
# 2020-11-05 16:00:00                                 NA
# 2020-11-05 17:00:00                                 NA
# 2020-11-05 18:00:00                                 NA
# 2020-11-05 19:00:00                                 NA
# 2020-11-05 20:00:00                                 NA
# 2020-11-05 21:00:00                                 NA
# 2020-11-05 22:00:00                                 NA

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Time series plot

# %%
options(repr.plot.width=20, repr.plot.height=6)
plot(j, type="l", col='red', lwd=0.5, main="Total Active Energy", ylab="kwh")
# Out:
# plot without title

# %% [markdown]
# ## Outlier handling

# %% [markdown]
# 2 methods are used to detect outliers (forecast package):
# 1. tsclean which implements loess decomposition of time series to identify and replace outliers
# 2. tsoutliers function which implements the Chen and Liu method
# Results are exactly the same for both. No outliers are detected at all.

# %%
setdiff(tsclean(j)$Diff.Load.Activa.Total..60.minuto., j$Diff.Load.Activa.Total..60.minuto.)
# Out:
# numeric(0)

# %%
tsoutliers(j)
# Out:
# $index
# integer(0)
#
# $replacements
#      Diff.Load.Activa.Total..60.minuto.

# %% [markdown]
# ## Transforms

# %%
lj=log(j) # compute the logartithm of the ts
dlj=diff(lj)

# %%
options(repr.plot.width=20, repr.plot.height=20)
par(mfrow=c(3,2)) # set up the graphics
plot(j,type="l", col='red', lwd=1,main="Time Series plot of Total Active Energy", ylab="kwh")
hist(j, nclass=25, main="Histogram of Total Active Energy")
plot(lj,type="l", col='red', lwd=1,main="Log of Total Active Energy", ylab="Log of kwh")
hist(lj, nclass=25, main="Histogram of log of Total Active Energy")
plot(dlj,type="l", col='red', lwd=1,main="Differences of log of Total Active Energy")
hist(dlj, nclass=25, main="Histogram of differences of log of Total Active Energy")
# Out:
# Plot with title “Histogram of differences of log of Total Active Energy”

# %% [markdown]
# It is observed that following the transformations the time series seems much closer to stationary, excluding the heteroskedasticity that it continues to demonstrate. Additionally it comes very close to a normal distribution.

# %%
par(mfrow=c(3,2)) # set up the graphics
acf(ts(j, freq=1), 100, main="ACF of Total Active Energy") # autocorrelation function plot
pacf(ts(j, freq=1), 100, main="PACF of Total Active Energy") # partial autocorrelation function
acf(ts(lj, freq=1), 100, main="ACF of log of Total Active Energy")
pacf(ts(lj, freq=1), 100, main="PACF of log of Total Active Energy")
acf(ts(dlj, freq=1), 100, main="ACF of differences of log of Total Active Energy", na.action = na.pass)
pacf(ts(dlj, freq=1), 100, main="PACF of differences of log of Total Active Energy", na.action = na.pass)
# Out:
# Plot with title “PACF of differences of log of Total Active Energy”

# %% [markdown]
# ## Unit root testing

# %% [markdown]
# ### Drift

# %% [markdown]
# #### Original time series

# %%
m=ar(j)
m
m$order
m1=ur.df(j,type="drift",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = j)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
#  0.4784   0.0983   0.1171  -0.0527   0.0186   0.0482   0.0283  -0.0388
#       9       10       11       12       13       14       15       16
#  0.0309  -0.0066   0.0152  -0.0076  -0.0077  -0.0057  -0.0278  -0.0109
#      17       18       19       20       21       22       23       24
#  0.0230   0.0417   0.0217   0.0271   0.0008   0.0320   0.1034   0.2099
#      25       26       27       28       29       30       31       32
# -0.0160  -0.0496  -0.0394   0.0064   0.0034  -0.0227  -0.0214  -0.0358
#
# Order selected 32  sigma^2 estimated as  84236
# [1] 32
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -3.7938 7.2432
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1514.99  -128.37     6.61   133.63  1746.86
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  99.063514  26.699985   3.710 0.000209 ***
# z.lag.1      -0.035579   0.009378  -3.794 0.000150 ***
# z.diff.lag1  -0.495407   0.015908 -31.143  < 2e-16 ***
# z.diff.lag2  -0.399034   0.017222 -23.169  < 2e-16 ***
# z.diff.lag3  -0.283368   0.018014 -15.731  < 2e-16 ***
# z.diff.lag4  -0.336318   0.018396 -18.282  < 2e-16 ***
# z.diff.lag5  -0.317512   0.018926 -16.777  < 2e-16 ***
# z.diff.lag6  -0.268534   0.019364 -13.868  < 2e-16 ***
# z.diff.lag7  -0.239188   0.019626 -12.187  < 2e-16 ***
# z.diff.lag8  -0.276389   0.019801 -13.958  < 2e-16 ***
# z.diff.lag9  -0.244685   0.020113 -12.165  < 2e-16 ***
# z.diff.lag10 -0.249962   0.020230 -12.356  < 2e-16 ***
# z.diff.lag11 -0.234296   0.020298 -11.543  < 2e-16 ***
# z.diff.lag12 -0.241654   0.020327 -11.888  < 2e-16 ***
# z.diff.lag13 -0.249504   0.020319 -12.280  < 2e-16 ***
# z.diff.lag14 -0.254064   0.020273 -12.532  < 2e-16 ***
# z.diff.lag15 -0.282435   0.020130 -14.031  < 2e-16 ***
# z.diff.lag16 -0.294534   0.019993 -14.732  < 2e-16 ***
# z.diff.lag17 -0.271605   0.019920 -13.635  < 2e-16 ***
# z.diff.lag18 -0.229516   0.019863 -11.555  < 2e-16 ***
# z.diff.lag19 -0.207477   0.019729 -10.516  < 2e-16 ***
# z.diff.lag20 -0.179592   0.019569  -9.177  < 2e-16 ***
# z.diff.lag21 -0.177366   0.019370  -9.157  < 2e-16 ***
# z.diff.lag22 -0.144506   0.019125  -7.556 4.82e-14 ***
# z.diff.lag23 -0.040457   0.018849  -2.146 0.031887 *
# z.diff.lag24  0.170496   0.018390   9.271  < 2e-16 ***
# z.diff.lag25  0.157858   0.018161   8.692  < 2e-16 ***
# z.diff.lag26  0.111540   0.017827   6.257 4.22e-10 ***
# z.diff.lag27  0.073555   0.017270   4.259 2.09e-05 ***
# z.diff.lag28  0.080114   0.016581   4.832 1.39e-06 ***
# z.diff.lag29  0.083595   0.016062   5.204 2.01e-07 ***
# z.diff.lag30  0.060602   0.015040   4.029 5.66e-05 ***
# z.diff.lag31  0.038565   0.013321   2.895 0.003805 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 289.1 on 5635 degrees of freedom
# Multiple R-squared:  0.3038,	Adjusted R-squared:  0.2998
# F-statistic: 76.83 on 32 and 5635 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -3.7938 7.2432
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# #### Log time series

# %%
m=ar(lj)
m
m$order
m1=ur.df(lj,type="drift",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = lj)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
# -0.0491   0.3111   0.3961   0.0627  -0.0985   0.1163  -0.0417   0.0127
#       9       10       11       12       13       14       15       16
#  0.0332   0.0232   0.0073   0.0005   0.0038   0.0217   0.0054  -0.0306
#      17       18       19       20       21       22       23       24
#  0.0014  -0.0051  -0.0091  -0.0285   0.0045   0.0136  -0.0010  -0.0157
#      25       26       27       28       29       30       31       32
# -0.0200  -0.0030   0.0056   0.0007  -0.0225  -0.0177  -0.0051  -0.0017
#      33       34       35       36       37       38       39       40
#  0.0130   0.0193   0.0635   0.0208   0.0033   0.0274   0.0565   0.0637
#
# Order selected 40  sigma^2 estimated as  0.04075
# [1] 40
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -5.4351 14.7948
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.55851 -0.07889  0.01921  0.10249  1.31110
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.434760   0.080090   5.428 5.80e-08 ***
# z.lag.1      -0.060320   0.011098  -5.435 5.59e-08 ***
# z.diff.lag1  -0.990750   0.014136 -70.087  < 2e-16 ***
# z.diff.lag2  -0.681194   0.016842 -40.445  < 2e-16 ***
# z.diff.lag3  -0.285721   0.017912 -15.951  < 2e-16 ***
# z.diff.lag4  -0.222952   0.018002 -12.385  < 2e-16 ***
# z.diff.lag5  -0.321370   0.017985 -17.869  < 2e-16 ***
# z.diff.lag6  -0.204911   0.018015 -11.375  < 2e-16 ***
# z.diff.lag7  -0.246484   0.017866 -13.797  < 2e-16 ***
# z.diff.lag8  -0.233762   0.017745 -13.173  < 2e-16 ***
# z.diff.lag9  -0.200448   0.017614 -11.380  < 2e-16 ***
# z.diff.lag10 -0.177021   0.017445 -10.147  < 2e-16 ***
# z.diff.lag11 -0.169180   0.017282  -9.789  < 2e-16 ***
# z.diff.lag12 -0.168414   0.017145  -9.823  < 2e-16 ***
# z.diff.lag13 -0.164457   0.017005  -9.671  < 2e-16 ***
# z.diff.lag14 -0.142458   0.016852  -8.453  < 2e-16 ***
# z.diff.lag15 -0.137002   0.016684  -8.212 2.42e-16 ***
# z.diff.lag16 -0.167560   0.016540 -10.131  < 2e-16 ***
# z.diff.lag17 -0.166090   0.016444 -10.100  < 2e-16 ***
# z.diff.lag18 -0.170878   0.016347 -10.453  < 2e-16 ***
# z.diff.lag19 -0.179528   0.016236 -11.057  < 2e-16 ***
# z.diff.lag20 -0.208123   0.016124 -12.908  < 2e-16 ***
# z.diff.lag21 -0.203875   0.016077 -12.681  < 2e-16 ***
# z.diff.lag22 -0.190067   0.016036 -11.852  < 2e-16 ***
# z.diff.lag23 -0.191305   0.015990 -11.964  < 2e-16 ***
# z.diff.lag24 -0.207324   0.015945 -13.002  < 2e-16 ***
# z.diff.lag25 -0.227535   0.015956 -14.260  < 2e-16 ***
# z.diff.lag26 -0.230826   0.015985 -14.440  < 2e-16 ***
# z.diff.lag27 -0.225306   0.015990 -14.091  < 2e-16 ***
# z.diff.lag28 -0.224432   0.015985 -14.040  < 2e-16 ***
# z.diff.lag29 -0.246937   0.015977 -15.456  < 2e-16 ***
# z.diff.lag30 -0.264839   0.015990 -16.563  < 2e-16 ***
# z.diff.lag31 -0.270017   0.015996 -16.880  < 2e-16 ***
# z.diff.lag32 -0.271618   0.015957 -17.022  < 2e-16 ***
# z.diff.lag33 -0.258558   0.015898 -16.263  < 2e-16 ***
# z.diff.lag34 -0.239145   0.015886 -15.054  < 2e-16 ***
# z.diff.lag35 -0.175032   0.015638 -11.192  < 2e-16 ***
# z.diff.lag36 -0.154071   0.015500  -9.940  < 2e-16 ***
# z.diff.lag37 -0.150496   0.015224  -9.885  < 2e-16 ***
# z.diff.lag38 -0.122449   0.013615  -8.994  < 2e-16 ***
# z.diff.lag39 -0.064895   0.009419  -6.890 5.88e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.202 on 11317 degrees of freedom
# Multiple R-squared:  0.5986,	Adjusted R-squared:  0.5972
# F-statistic: 421.9 on 40 and 11317 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -5.4351 14.7948
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# #### Diff log time series
# This time series needs to be imputed with tsclean in order to be processed as it has missing values. But why missing values here. The simple logarithm transformation was ok! Is it only the first?

# %%
m=ar(tsclean(dlj))
m
m$order
m1=ur.df(tsclean(dlj),type="drift", lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = tsclean(dlj))
#
# Coefficients:
#       1        2        3        4        5        6        7        8
# -0.4431   0.0854   0.0352  -0.0056  -0.0551   0.0733   0.0296  -0.0231
#       9       10       11       12       13       14       15       16
# -0.0601  -0.0446  -0.0134   0.0252   0.0148   0.0196   0.0197  -0.0340
#      17       18       19       20       21       22       23       24
# -0.0245  -0.0133   0.0090  -0.0127  -0.0032   0.0120   0.0182   0.0022
#      25       26       27       28       29       30       31       32
# -0.0213   0.0023  -0.0090  -0.0059   0.0023   0.0079   0.0033  -0.0252
#      33       34       35       36       37       38       39       40
# -0.0223   0.0077   0.0077   0.0002   0.0256   0.0267   0.0289   0.0413
#
# Order selected 40  sigma^2 estimated as  0.05064
# [1] 40
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -16.0508 128.8146
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression drift
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.16675 -0.09774  0.00142  0.10505  1.37138
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.0007826  0.0021157  -0.370 0.711458
# z.lag.1      -1.3188153  0.0821651 -16.051  < 2e-16 ***
# z.diff.lag1  -0.1243434  0.0812194  -1.531 0.125808
# z.diff.lag2  -0.0390270  0.0801712  -0.487 0.626412
# z.diff.lag3  -0.0038488  0.0790588  -0.049 0.961173
# z.diff.lag4  -0.0094293  0.0778878  -0.121 0.903643
# z.diff.lag5  -0.0645561  0.0766992  -0.842 0.399986
# z.diff.lag6   0.0087224  0.0754813   0.116 0.908006
# z.diff.lag7   0.0383545  0.0742270   0.517 0.605363
# z.diff.lag8   0.0151143  0.0729919   0.207 0.835961
# z.diff.lag9  -0.0450789  0.0717791  -0.628 0.530002
# z.diff.lag10 -0.0898067  0.0705403  -1.273 0.202999
# z.diff.lag11 -0.1032530  0.0692686  -1.491 0.136090
# z.diff.lag12 -0.0779827  0.0679700  -1.147 0.251278
# z.diff.lag13 -0.0632279  0.0666547  -0.949 0.342850
# z.diff.lag14 -0.0435086  0.0653290  -0.666 0.505430
# z.diff.lag15 -0.0236689  0.0639692  -0.370 0.711386
# z.diff.lag16 -0.0578149  0.0626223  -0.923 0.355906
# z.diff.lag17 -0.0824620  0.0612421  -1.346 0.178171
# z.diff.lag18 -0.0957910  0.0597974  -1.602 0.109200
# z.diff.lag19 -0.0868194  0.0582932  -1.489 0.136422
# z.diff.lag20 -0.0995758  0.0567509  -1.755 0.079353 .
# z.diff.lag21 -0.1028293  0.0551985  -1.863 0.062502 .
# z.diff.lag22 -0.0906525  0.0535853  -1.692 0.090723 .
# z.diff.lag23 -0.0721520  0.0519507  -1.389 0.164905
# z.diff.lag24 -0.0701063  0.0503188  -1.393 0.163574
# z.diff.lag25 -0.0914928  0.0487168  -1.878 0.060400 .
# z.diff.lag26 -0.0890891  0.0470172  -1.895 0.058142 .
# z.diff.lag27 -0.0982386  0.0451941  -2.174 0.029748 *
# z.diff.lag28 -0.1043798  0.0432494  -2.413 0.015819 *
# z.diff.lag29 -0.1019965  0.0411447  -2.479 0.013191 *
# z.diff.lag30 -0.0939406  0.0389725  -2.410 0.015949 *
# z.diff.lag31 -0.0905128  0.0368136  -2.459 0.013960 *
# z.diff.lag32 -0.1159784  0.0347241  -3.340 0.000841 ***
# z.diff.lag33 -0.1386601  0.0325976  -4.254 2.12e-05 ***
# z.diff.lag34 -0.1306789  0.0302156  -4.325 1.54e-05 ***
# z.diff.lag35 -0.1231171  0.0272970  -4.510 6.54e-06 ***
# z.diff.lag36 -0.1232188  0.0242874  -5.073 3.97e-07 ***
# z.diff.lag37 -0.0973557  0.0208840  -4.662 3.17e-06 ***
# z.diff.lag38 -0.0704630  0.0165477  -4.258 2.08e-05 ***
# z.diff.lag39 -0.0415443  0.0094355  -4.403 1.08e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2254 on 11317 degrees of freedom
# Multiple R-squared:  0.7493,	Adjusted R-squared:  0.7484
# F-statistic: 845.6 on 40 and 11317 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -16.0508 128.8146
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau2 -3.43 -2.86 -2.57
# phi1  6.43  4.59  3.78

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to drift.

# %% [markdown]
# ### Trend

# %% [markdown]
# #### Original time series

# %%
m=ar(j)
m
m$order
m1=ur.df(j,type="trend",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = j)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
# -0.0025   0.4379   0.2976   0.0208  -0.1061   0.1131  -0.0136  -0.0020
#       9       10       11       12       13       14       15       16
#  0.0346   0.0169  -0.0009   0.0160   0.0088   0.0248  -0.0129  -0.0692
#      17       18       19       20       21       22       23       24
# -0.0102   0.0114   0.0168  -0.0188   0.0021   0.0141  -0.0002  -0.0138
#      25       26       27       28       29       30       31       32
# -0.0150   0.0040   0.0025  -0.0078  -0.0146  -0.0100  -0.0111  -0.0332
#      33       34       35       36       37       38       39       40
#  0.0002   0.0482   0.0684   0.0113  -0.0079   0.0253   0.0569   0.0657
#
# Order selected 40  sigma^2 estimated as  46371
# [1] 40
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -7.272 17.6506 26.4503
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1211.00  -114.23    10.22   125.46  1052.71
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.589e+02  2.221e+01   7.151 9.16e-13 ***
# z.lag.1      -9.600e-02  1.320e-02  -7.272 3.78e-13 ***
# tt           -4.213e-03  8.374e-04  -5.031 4.95e-07 ***
# z.diff.lag1  -9.119e-01  1.563e-02 -58.352  < 2e-16 ***
# z.diff.lag2  -4.785e-01  1.771e-02 -27.021  < 2e-16 ***
# z.diff.lag3  -1.827e-01  1.813e-02 -10.074  < 2e-16 ***
# z.diff.lag4  -1.626e-01  1.809e-02  -8.989  < 2e-16 ***
# z.diff.lag5  -2.695e-01  1.801e-02 -14.969  < 2e-16 ***
# z.diff.lag6  -1.577e-01  1.795e-02  -8.790  < 2e-16 ***
# z.diff.lag7  -1.720e-01  1.769e-02  -9.725  < 2e-16 ***
# z.diff.lag8  -1.750e-01  1.744e-02 -10.032  < 2e-16 ***
# z.diff.lag9  -1.413e-01  1.726e-02  -8.188 2.94e-16 ***
# z.diff.lag10 -1.251e-01  1.706e-02  -7.331 2.43e-13 ***
# z.diff.lag11 -1.264e-01  1.687e-02  -7.494 7.16e-14 ***
# z.diff.lag12 -1.107e-01  1.670e-02  -6.632 3.46e-11 ***
# z.diff.lag13 -1.022e-01  1.653e-02  -6.186 6.39e-10 ***
# z.diff.lag14 -7.775e-02  1.635e-02  -4.755 2.01e-06 ***
# z.diff.lag15 -9.136e-02  1.615e-02  -5.656 1.59e-08 ***
# z.diff.lag16 -1.617e-01  1.598e-02 -10.116  < 2e-16 ***
# z.diff.lag17 -1.728e-01  1.589e-02 -10.875  < 2e-16 ***
# z.diff.lag18 -1.616e-01  1.580e-02 -10.229  < 2e-16 ***
# z.diff.lag19 -1.449e-01  1.568e-02  -9.243  < 2e-16 ***
# z.diff.lag20 -1.645e-01  1.554e-02 -10.582  < 2e-16 ***
# z.diff.lag21 -1.638e-01  1.545e-02 -10.601  < 2e-16 ***
# z.diff.lag22 -1.509e-01  1.533e-02  -9.841  < 2e-16 ***
# z.diff.lag23 -1.522e-01  1.518e-02 -10.024  < 2e-16 ***
# z.diff.lag24 -1.671e-01  1.506e-02 -11.097  < 2e-16 ***
# z.diff.lag25 -1.831e-01  1.504e-02 -12.173  < 2e-16 ***
# z.diff.lag26 -1.802e-01  1.505e-02 -11.974  < 2e-16 ***
# z.diff.lag27 -1.788e-01  1.503e-02 -11.898  < 2e-16 ***
# z.diff.lag28 -1.873e-01  1.500e-02 -12.488  < 2e-16 ***
# z.diff.lag29 -2.027e-01  1.496e-02 -13.551  < 2e-16 ***
# z.diff.lag30 -2.138e-01  1.494e-02 -14.311  < 2e-16 ***
# z.diff.lag31 -2.260e-01  1.491e-02 -15.158  < 2e-16 ***
# z.diff.lag32 -2.605e-01  1.484e-02 -17.548  < 2e-16 ***
# z.diff.lag33 -2.616e-01  1.483e-02 -17.638  < 2e-16 ***
# z.diff.lag34 -2.143e-01  1.485e-02 -14.434  < 2e-16 ***
# z.diff.lag35 -1.465e-01  1.459e-02 -10.040  < 2e-16 ***
# z.diff.lag36 -1.356e-01  1.445e-02  -9.383  < 2e-16 ***
# z.diff.lag37 -1.441e-01  1.427e-02 -10.095  < 2e-16 ***
# z.diff.lag38 -1.198e-01  1.329e-02  -9.013  < 2e-16 ***
# z.diff.lag39 -6.441e-02  9.401e-03  -6.851 7.69e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 215.1 on 11316 degrees of freedom
# Multiple R-squared:  0.5768,	Adjusted R-squared:  0.5752
# F-statistic: 376.1 on 41 and 11316 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -7.272 17.6506 26.4503
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %% [markdown]
# #### Log time series

# %%
m=ar(lj)
m
m$order
m1=ur.df(lj,type="trend",lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = lj)
#
# Coefficients:
#       1        2        3        4        5        6        7        8
# -0.0491   0.3111   0.3961   0.0627  -0.0985   0.1163  -0.0417   0.0127
#       9       10       11       12       13       14       15       16
#  0.0332   0.0232   0.0073   0.0005   0.0038   0.0217   0.0054  -0.0306
#      17       18       19       20       21       22       23       24
#  0.0014  -0.0051  -0.0091  -0.0285   0.0045   0.0136  -0.0010  -0.0157
#      25       26       27       28       29       30       31       32
# -0.0200  -0.0030   0.0056   0.0007  -0.0225  -0.0177  -0.0051  -0.0017
#      33       34       35       36       37       38       39       40
#  0.0130   0.0193   0.0635   0.0208   0.0033   0.0274   0.0565   0.0637
#
# Order selected 40  sigma^2 estimated as  0.04075
# [1] 40
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -7.5396 18.9739 28.4363
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.54599 -0.07998  0.01805  0.10201  1.30731
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   8.417e-01  1.117e-01   7.536 5.20e-14 ***
# z.lag.1      -1.135e-01  1.505e-02  -7.540 5.07e-14 ***
# tt           -4.093e-06  7.840e-07  -5.221 1.81e-07 ***
# z.diff.lag1  -9.401e-01  1.713e-02 -54.896  < 2e-16 ***
# z.diff.lag2  -6.334e-01  1.915e-02 -33.073  < 2e-16 ***
# z.diff.lag3  -2.401e-01  1.991e-02 -12.055  < 2e-16 ***
# z.diff.lag4  -1.785e-01  1.990e-02  -8.971  < 2e-16 ***
# z.diff.lag5  -2.780e-01  1.979e-02 -14.045  < 2e-16 ***
# z.diff.lag6  -1.630e-01  1.970e-02  -8.272  < 2e-16 ***
# z.diff.lag7  -2.058e-01  1.947e-02 -10.569  < 2e-16 ***
# z.diff.lag8  -1.945e-01  1.926e-02 -10.098  < 2e-16 ***
# z.diff.lag9  -1.625e-01  1.904e-02  -8.535  < 2e-16 ***
# z.diff.lag10 -1.403e-01  1.879e-02  -7.465 8.91e-14 ***
# z.diff.lag11 -1.336e-01  1.856e-02  -7.197 6.54e-13 ***
# z.diff.lag12 -1.339e-01  1.836e-02  -7.292 3.25e-13 ***
# z.diff.lag13 -1.310e-01  1.815e-02  -7.215 5.76e-13 ***
# z.diff.lag14 -1.101e-01  1.794e-02  -6.134 8.84e-10 ***
# z.diff.lag15 -1.056e-01  1.772e-02  -5.961 2.58e-09 ***
# z.diff.lag16 -1.371e-01  1.752e-02  -7.826 5.48e-15 ***
# z.diff.lag17 -1.366e-01  1.737e-02  -7.867 3.96e-15 ***
# z.diff.lag18 -1.424e-01  1.722e-02  -8.271  < 2e-16 ***
# z.diff.lag19 -1.521e-01  1.705e-02  -8.918  < 2e-16 ***
# z.diff.lag20 -1.817e-01  1.688e-02 -10.763  < 2e-16 ***
# z.diff.lag21 -1.785e-01  1.678e-02 -10.637  < 2e-16 ***
# z.diff.lag22 -1.657e-01  1.668e-02  -9.930  < 2e-16 ***
# z.diff.lag23 -1.679e-01  1.659e-02 -10.120  < 2e-16 ***
# z.diff.lag24 -1.849e-01  1.650e-02 -11.207  < 2e-16 ***
# z.diff.lag25 -2.060e-01  1.646e-02 -12.516  < 2e-16 ***
# z.diff.lag26 -2.103e-01  1.644e-02 -12.793  < 2e-16 ***
# z.diff.lag27 -2.059e-01  1.640e-02 -12.554  < 2e-16 ***
# z.diff.lag28 -2.061e-01  1.635e-02 -12.603  < 2e-16 ***
# z.diff.lag29 -2.296e-01  1.630e-02 -14.088  < 2e-16 ***
# z.diff.lag30 -2.487e-01  1.627e-02 -15.283  < 2e-16 ***
# z.diff.lag31 -2.551e-01  1.623e-02 -15.713  < 2e-16 ***
# z.diff.lag32 -2.580e-01  1.615e-02 -15.973  < 2e-16 ***
# z.diff.lag33 -2.463e-01  1.605e-02 -15.342  < 2e-16 ***
# z.diff.lag34 -2.281e-01  1.601e-02 -14.250  < 2e-16 ***
# z.diff.lag35 -1.655e-01  1.573e-02 -10.520  < 2e-16 ***
# z.diff.lag36 -1.456e-01  1.557e-02  -9.350  < 2e-16 ***
# z.diff.lag37 -1.432e-01  1.527e-02  -9.374  < 2e-16 ***
# z.diff.lag38 -1.172e-01  1.364e-02  -8.595  < 2e-16 ***
# z.diff.lag39 -6.239e-02  9.420e-03  -6.623 3.67e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2018 on 11316 degrees of freedom
# Multiple R-squared:  0.5996,	Adjusted R-squared:  0.5981
# F-statistic: 413.3 on 41 and 11316 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -7.5396 18.9739 28.4363
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %% [markdown]
# #### Diff log time series
# This time series needs to be imputed with tsclean in order to be processed as it has missing values. But why missing values here. The simple logarithm transformation was ok! Is it only the first?

# %%
m=ar(tsclean(dlj))
m
m$order
m1=ur.df(tsclean(dlj),type="trend", lags=m$order-1)
m1
summary(m1)
# Out:
# Call:
# ar(x = tsclean(dlj))
#
# Coefficients:
#       1        2        3        4        5        6        7        8
# -0.4431   0.0854   0.0352  -0.0056  -0.0551   0.0733   0.0296  -0.0231
#       9       10       11       12       13       14       15       16
# -0.0601  -0.0446  -0.0134   0.0252   0.0148   0.0196   0.0197  -0.0340
#      17       18       19       20       21       22       23       24
# -0.0245  -0.0133   0.0090  -0.0127  -0.0032   0.0120   0.0182   0.0022
#      25       26       27       28       29       30       31       32
# -0.0213   0.0023  -0.0090  -0.0059   0.0023   0.0079   0.0033  -0.0252
#      33       34       35       36       37       38       39       40
# -0.0223   0.0077   0.0077   0.0002   0.0256   0.0267   0.0289   0.0413
#
# Order selected 40  sigma^2 estimated as  0.05064
# [1] 40
# ###############################################################
# # Augmented Dickey-Fuller Test Unit Root / Cointegration Test #
# ###############################################################
#
# The value of the test statistic is: -16.0822 86.2131 129.3189
# ###############################################
# # Augmented Dickey-Fuller Test Unit Root Test #
# ###############################################
#
# Test regression trend
#
#
# Call:
# lm(formula = z.diff ~ z.lag.1 + 1 + tt + z.diff.lag)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.16323 -0.09757  0.00066  0.10579  1.37431
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.928e-03  4.256e-03   0.688 0.491471
# z.lag.1      -1.324e+00  8.233e-02 -16.082  < 2e-16 ***
# tt           -6.495e-07  6.464e-07  -1.005 0.314999
# z.diff.lag1  -1.192e-01  8.138e-02  -1.464 0.143109
# z.diff.lag2  -3.400e-02  8.033e-02  -0.423 0.672141
# z.diff.lag3   1.048e-03  7.921e-02   0.013 0.989447
# z.diff.lag4  -4.668e-03  7.803e-02  -0.060 0.952294
# z.diff.lag5  -5.993e-02  7.684e-02  -0.780 0.435446
# z.diff.lag6   1.321e-02  7.561e-02   0.175 0.861304
# z.diff.lag7   4.271e-02  7.435e-02   0.574 0.565690
# z.diff.lag8   1.934e-02  7.311e-02   0.265 0.791331
# z.diff.lag9  -4.097e-02  7.190e-02  -0.570 0.568748
# z.diff.lag10 -8.584e-02  7.065e-02  -1.215 0.224421
# z.diff.lag11 -9.942e-02  6.937e-02  -1.433 0.151840
# z.diff.lag12 -7.430e-02  6.807e-02  -1.091 0.275090
# z.diff.lag13 -5.968e-02  6.675e-02  -0.894 0.371295
# z.diff.lag14 -4.010e-02  6.542e-02  -0.613 0.539911
# z.diff.lag15 -2.039e-02  6.405e-02  -0.318 0.750190
# z.diff.lag16 -5.467e-02  6.270e-02  -0.872 0.383296
# z.diff.lag17 -7.944e-02  6.132e-02  -1.296 0.195134
# z.diff.lag18 -9.290e-02  5.987e-02  -1.552 0.120731
# z.diff.lag19 -8.407e-02  5.836e-02  -1.441 0.149746
# z.diff.lag20 -9.696e-02  5.681e-02  -1.707 0.087913 .
# z.diff.lag21 -1.003e-01  5.525e-02  -1.816 0.069382 .
# z.diff.lag22 -8.831e-02  5.364e-02  -1.646 0.099691 .
# z.diff.lag23 -6.995e-02  5.200e-02  -1.345 0.178553
# z.diff.lag24 -6.804e-02  5.036e-02  -1.351 0.176723
# z.diff.lag25 -8.955e-02  4.876e-02  -1.837 0.066268 .
# z.diff.lag26 -8.729e-02  4.705e-02  -1.855 0.063604 .
# z.diff.lag27 -9.657e-02  4.522e-02  -2.135 0.032752 *
# z.diff.lag28 -1.028e-01  4.328e-02  -2.377 0.017493 *
# z.diff.lag29 -1.006e-01  4.117e-02  -2.444 0.014552 *
# z.diff.lag30 -9.268e-02  3.899e-02  -2.377 0.017475 *
# z.diff.lag31 -8.939e-02  3.683e-02  -2.427 0.015243 *
# z.diff.lag32 -1.150e-01  3.474e-02  -3.310 0.000937 ***
# z.diff.lag33 -1.378e-01  3.261e-02  -4.225 2.41e-05 ***
# z.diff.lag34 -1.299e-01  3.022e-02  -4.299 1.73e-05 ***
# z.diff.lag35 -1.225e-01  2.730e-02  -4.487 7.31e-06 ***
# z.diff.lag36 -1.227e-01  2.429e-02  -5.052 4.43e-07 ***
# z.diff.lag37 -9.700e-02  2.089e-02  -4.644 3.46e-06 ***
# z.diff.lag38 -7.023e-02  1.655e-02  -4.244 2.21e-05 ***
# z.diff.lag39 -4.145e-02  9.436e-03  -4.393 1.13e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2254 on 11316 degrees of freedom
# Multiple R-squared:  0.7493,	Adjusted R-squared:  0.7484
# F-statistic:   825 on 41 and 11316 DF,  p-value: < 2.2e-16
#
#
# Value of test-statistic is: -16.0822 86.2131 129.3189
#
# Critical values for test statistics:
#       1pct  5pct 10pct
# tau3 -3.96 -3.41 -3.12
# phi2  6.09  4.68  4.03
# phi3  8.27  6.25  5.34

# %%
acf(j, 48, main="ACF of Total Active Energy") # autocorrelation function plot
pacf(j, 48, main="PACF of Total Active Energy") # partial autocorrelation function
acf(lj, 48, main="ACF of log of Total Active Energy")
pacf(lj, 48, main="PACF of log of Total Active Energy")
acf(dlj, 48, main="ACF of differences of log of Total Active Energy", na.action = na.pass)
pacf(dlj, 48, main="PACF of differences of log of Total Active Energy", na.action = na.pass)
# Out:
# Plot with title “ACF of Total Active Energy”
# Plot with title “PACF of Total Active Energy”
# Plot with title “ACF of log of Total Active Energy”
# Plot with title “PACF of log of Total Active Energy”
# Plot with title “ACF of differences of log of Total Active Energy”
# Plot with title “PACF of differences of log of Total Active Energy”

# %% [markdown]
# The null hypothesis of non-stationarity is rejected for all cases with respect to trend.

# %% [markdown]
# ## Normality tests

# %%
shapiro.test(sample(coredata(j), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(j, prob=TRUE, 15) # histogram
lines(density(j)) # smooth it - ?density for details
qqnorm(j,main="Normal QQplot of timeseries") # normal Q-Q plot
qqline(j)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(j), 5000, replace = FALSE)
# W = 0.97655, p-value < 2.2e-16
# Plot with title “Normal QQplot of timeseries”

# %%
shapiro.test(sample(coredata(lj), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(lj, prob=TRUE, 15) # histogram
lines(density(lj)) # smooth it - ?density for details
qqnorm(lj,main="Normal QQplot of log timeseries") # normal Q-Q plot
qqline(lj)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(lj), 5000, replace = FALSE)
# W = 0.85762, p-value < 2.2e-16
# Plot with title “Normal QQplot of log timeseries”

# %%
shapiro.test(sample(coredata(dlj), 5000, replace=FALSE))

par(mfrow=c(2,1))
hist(tsclean(dlj), prob=TRUE, 15) # histogram
lines(density(tsclean(dlj))) # smooth it - ?density for details
qqnorm(lj,main="Normal QQplot of diff log timeseries") # normal Q-Q plot
qqline(lj)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(dlj), 5000, replace = FALSE)
# W = 0.91625, p-value < 2.2e-16
# Plot with title “Normal QQplot of diff log timeseries”

# %% [markdown]
# Null hypothesis for normality is rejected in all cases according to the Shapiro tests and qqplots. So we will need to consider the BoxCox transformation in the training process.

# %% [markdown]
# ### Box Cox transform
# A sample Box Cox transformation

# %%
normalised=BoxCox(j, 2)
shapiro.test(sample(coredata(normalised), 5000, replace=FALSE))
par(mfrow=c(2,1))
hist(normalised, prob=TRUE, 15) # histogram
lines(density(tsclean(normalised))) # smooth it - ?density for details
qqnorm(normalised,main="Normal QQplot of diff log timeseries") # normal Q-Q plot
qqline(normalised)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  sample(coredata(normalised), 5000, replace = FALSE)
# W = 0.99122, p-value < 2.2e-16
# Plot with title “Normal QQplot of diff log timeseries”

# %%
ltrain = lj['/2021-06-15 23:30:00']
ltest = lj['2021-06-16 00:00:00/']

# %%
### auto.arima

# %%
auto <- auto.arima(tsclean(ltrain), stepwise=FALSE, approximation=FALSE, num.cores=6, lambda='auto', biasadj=TRUE)

# %%
summary(auto)
# Out:
# Series: tsclean(ltrain)
# ARIMA(3,1,1)
# Box Cox transformation: lambda= 1.999927
#
# Coefficients:
#          ar1     ar2     ar3      ma1
#       0.0750  0.4710  0.1387  -0.9894
# s.e.  0.0097  0.0087  0.0097   0.0015
#
# sigma^2 estimated as 1.35:  log likelihood=-16749.35
# AIC=33508.69   AICc=33508.7   BIC=33545.07
#
# Training set error measures:
#                        ME      RMSE       MAE         MPE     MAPE       MASE
# Training set -0.001492005 0.1646154 0.1166002 -0.07424605 1.636751 0.01608706
#                   ACF1
# Training set -0.013778

# %%
### tbats

# %% [markdown]
# Seasonal periods: 48 (daily), 336 (weekly). (1 day = 48 * 30 min timesteps)

# %%
tb <- tbats(tsclean(ltrain), use.box.cox = TRUE, use.trend = TRUE, use.damped.trend=TRUE, 
               seasonal.periods=c(48, 336), use.arma.errors=TRUE, 
               use.parallel=TRUE, num.cores=6, biasadj=TRUE)
tb
# Out:
# TBATS(1, {5,4}, 0.991, {<48,8>, <336,6>})
#
# Call: tbats(y = tsclean(ltrain), use.box.cox = TRUE, use.trend = TRUE,
#     use.damped.trend = TRUE, seasonal.periods = c(48, 336), use.arma.errors = TRUE,
#     use.parallel = TRUE, num.cores = 6, biasadj = TRUE)
#
# Parameters
#   Lambda: 1
#   Alpha: 0.2229734
#   Beta: -0.002194465
#   Damping Parameter: 0.990972
#   Gamma-1 Values: 7.230775e-05 0.0007894309
#   Gamma-2 Values: 8.724276e-05 -3.437389e-05
#   AR coefficients: -0.133469 0.307396 0.120498 -0.049532 -0.11325
#   MA coefficients: -0.051259 -0.095401 -0.047353 0.090672
#
# Seed States:
#                [,1]
#  [1,]  6.6650081338
#  [2,] -0.0036400737
#  [3,]  0.0291392999
#  [4,] -0.0312363518
#  [5,]  0.0098267507
#  [6,] -0.0108755994
#  [7,] -0.0138389146
#  [8,] -0.0015928312
#  [9,] -0.0162441330
# [10,] -0.0051893949
# [11,]  0.0829356849
# [12,]  0.0111955093
# [13,]  0.0130683419
# [14,]  0.0219092710
# [15,] -0.0059353330
# [16,]  0.0022451484
# [17,]  0.0036042596
# [18,] -0.0087183841
# [19,] -0.0110562695
# [20,] -0.0002944588
# [21,]  0.0033770697
# [22,]  0.0076621337
# [23,]  0.0003318475
# [24,] -0.0049940410
# [25,]  0.0111295234
# [26,]  0.0002549439
# [27,] -0.0002955354
# [28,] -0.0050558819
# [29,] -0.0043716669
# [30,] -0.0021830682
# [31,]  0.0000000000
# [32,]  0.0000000000
# [33,]  0.0000000000
# [34,]  0.0000000000
# [35,]  0.0000000000
# [36,]  0.0000000000
# [37,]  0.0000000000
# [38,]  0.0000000000
# [39,]  0.0000000000
# attr(,"lambda")
# [1] 1
#
# Sigma: 0.1599845
# AIC: 60021.81

# %%
forecast <- predict(tb, 120)

# plot of forecasts with 1 standard error
par(mfrow=c(1,1))
UL <- forecast$meanForecast + forecast$meanError
LL <- forecast$meanForecast - forecast$meanError

predTS <- ts(forecast$meanForecast, frequency=120, start = c(2021, 06, 15, 23, 30, 00))
UL_TS <- ts(forecast$meanForecast, frequency=120, start = c(2021, 06, 15, 23, 30, 00))
LL_TS <- ts(forecast$meanForecast, frequency=120, start = c(2021, 06, 15, 23, 30, 00))

# min_x <- min(stepSRresidualsTS, LL)
# max_x <- max(stepSRresidualsTS, UL)

# ts.plot(stepSRresidualsTS, predTS)
lines(predTS, col="red", type="o")
lines(UL_TS, col="blue", lty="dashed")
lines(LL_TS, col="blue", lty="dashed")
# Out:
# Error in try.xts(0): Error in as.xts.double(x, ..., .RECLASS = TRUE) :   order.by must be either 'names()' or otherwise specified
# Traceback:
#
# 1. predict(tb, 120)
# 2. predict.default(tb, 120)
# 3. forecast(object, ...)
# 4. forecast.tbats(object, ...)
# 5. ts(c(object$y, 0), start = start.time, frequency = ts.frequency)
# 6. is.data.frame(data)
# 7. c(object$y, 0)
# 8. c.xts(object$y, 0)
# 9. try.xts(0)
# 10. stop(gsub("\n", "", xx))
